# %% [markdown]
# <a href="https://colab.research.google.com/github/beruscoder/gen-AI/blob/main/rag_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-openai \
               faiss-cpu tiktoken python-dotenv

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %%
video_id = "Gfr50f6ZBvo" # only the ID, not full URL
try:
    # If you don’t care which language, this returns the “best” one
    transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=["en"])

    # Flatten it to plain text
    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video.")
# Out:
# the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough to interview you well i'll be impressed if if you were i'd be impressed by myself if you were i don't think we're quite up to that yet but uh maybe you're from the future lex if you did would you tell me is that is that a good thing to tell a language model that's tasked with interviewing that it is in fact um ai maybe we're in a kind of meta turing test uh probably probably it would be a good idea not to tell you so it doesn't change your behavior right this is a kind of heisenberg uncertainty principle situation if i told you you behave differently yeah maybe that's what's happening with us of course this is a benchmark from the future where they replay 2022 as a year before ais were good enough yet and now we want to see is it going to pass exactly if i was such a program would you be able to tell do you think so to the touring test question you've talked about the benchmark for solving intelligence what would be the impressive thing you've talked about winning a nobel prize in a system winning a nobel prize but i still return to the touring test as a compelling test the spirit of the touring test is a compelling test yeah the turing test of course it's been unbelievably influential and turing's one of my all-time heroes but i think if you look back at the 1950 papers original paper and read the original you'll see i don't think he meant it to be a rigorous formal test i think it was more like a thought experiment almost a bit of philosophy he was writing if you look at the style of the paper and you can see he didn't specify it very rigorously so for example he didn't specify the knowledge that the expert or judge would have um not you know how much time would they have to investigate this so these important parameters if you were gonna make it uh a true sort of formal test um and you know some by some measures people claimed the turing test passed several you know a decade ago i remember someone claiming that with a with a kind of very bog standard normal uh logic model um because they pretended it was a it was a kid so the the judges thought that the machine you know was was a was a child so um that would be very different from an expert ai person uh interrogating a machine and knowing how it was built and so on so i think um you know we should probably move away from that as a formal test and move more towards a general test where we test the ai capabilities on a range of tasks and see if it reaches human level or above performance on maybe thousands perhaps even millions of tasks eventually and cover the entire sort of cognitive space so i think for its time it was an amazing thought experiment and also 1950s obviously it was barely the dawn of the computer age so of course he only thought about text and now um we have a lot more different inputs so yeah maybe the better thing to test is the generalizability so across multiple tasks but i think it's also possible as as systems like god show that eventually that might map right back to lan ...

# %%
transcript_list
# Out:
# [{'text': 'the following is a conversation with',
#   'start': 0.08,
#   'duration': 3.44},
#  {'text': 'demus hasabis', 'start': 1.76, 'duration': 4.96},
#  {'text': 'ceo and co-founder of deepmind', 'start': 3.52, 'duration': 5.119},
#  {'text': 'a company that has published and builds',
#   'start': 6.72,
#   'duration': 4.48},
#  {'text': 'some of the most incredible artificial',
#   'start': 8.639,
#   'duration': 4.561},
#  {'text': 'intelligence systems in the history of',
#   'start': 11.2,
#   'duration': 4.8},
#  {'text': 'computing including alfred zero that',
#   'start': 13.2,
#   'duration': 3.68},
#  {'text': 'learned', 'start': 16.0, 'duration': 2.96},
#  {'text': 'all by itself to play the game of gold',
#   'start': 16.88,
#   'duration': 4.559},
#  {'text': 'better than any human in the world and',
#   'start': 18.96,
#   'duration': 5.6},
#  {'text': 'alpha fold two that solved protein',
#   'start': 21.439,
#   'duration': 4.241},
#  {'text': 'folding', 'start': 24.56, 'duration': 4.16},
#  {'text': 'both tasks considered nearly impossible',
#   'start': 25.68,
#   'duration': 5.439},
#  {'text': 'for a very long time', 'start': 28.72, 'duration': 4.4},
#  {'text': 'demus is widely considered to be one of',
#   'start': 31.119,
#   'duration': 4.481},
#  {'text': 'the most brilliant and impactful humans',
#   'start': 33.12,
#   'duration': 4.0},
#  {'text': 'in the history of artificial', 'start': 35.6, 'duration': 4.24},
#  {'text': 'intelligence and science and engineering',
#   'start': 37.12,
#   'duration': 4.0},
#  {'text': 'in general', 'start': 39.84, 'duration': 3.92},
#  {'text': 'this was truly an honor and a pleasure',
#   'start': 41.12,
#   'duration': 4.959},
#  {'text': 'for me to finally sit down with him for',
#   'start': 43.76,
#   'duration': 4.799},
#  {'text': "this conversation and i'm sure we will",
#   'start': 46.079,
#   'duration': 5.361},
#  {'text': 'talk many times again in the future',
#   'start': 48.559,
#   'duration': 4.721},
#  {'text': 'this is the lex friedman podcast to',
#   'start': 51.44,
#   'duration': 4.0},
#  {'text': 'support it please check out our sponsors',
#   'start': 53.28,
#   'duration': 4.959},
#  {'text': 'in the description and now dear friends',
#   'start': 55.44,
#   'duration': 4.16},
#  {'text': "here's demis", 'start': 58.239, 'duration': 3.201},
#  {'text': 'hassabis', 'start': 59.6, 'duration': 3.36},
#  {'text': "let's start with a bit of a personal",
#   'start': 61.44,
#   'duration': 2.48},
#  {'text': 'question', 'start': 62.96, 'duration': 3.839},
#  {'text': 'am i an ai program you wrote to', 'start': 63.92, 'duration': 4.8},
#  {'text': 'interview people until i get good enough',
#   'start': 66.799,
#   'duration': 4.161},
#  {'text': 'to interview you', 'start': 68.72, 'duration': 4.24},
#  {'text': "well i'll be impressed if if you were",
#   'start': 70.96,
#   'duration': 3.839},
#  {'text': "i'd be impressed by myself if you were i",
#   'start': 72.96,
#   'duration': 3.44},
#  {'text': "don't think we're quite up to that yet",
#   'start': 74.799,
#   'duration': 3.921},
#  {'text': "but uh maybe you're from the future lex",
#   'start': 76.4,
#   'duration': 4.48},
#  {'text': 'if you did would you tell me is that is',
#   'start': 78.72,
#   'duration': 3.84},
#  {'text': 'that a good thing to tell a language',
#   'start': 80.88,
#   'duration': 4.08},
#  {'text': "model that's tasked with interviewing",
#   'start': 82.56,
#   'duration': 5.199},
#  {'text': "that it is in fact um ai maybe we're in",
#   'start': 84.96,
#   'duration': 5.28},
#  {'text': 'a kind of meta turing test uh probably',
#   'start': 87.759,
#   'duration': 4.081},
#  {'text': 'probably it would be a good idea not to',
#   'start': 90.24,
#   'duration': 2.96},
#  {'text': "tell you so it doesn't change your",
#   'start': 91.84,
#   'duration': 2.88},
#  {'text': 'behavior right this is a kind of', 'start': 93.2, 'duration': 3.2},
#  {'text': 'heisenberg uncertainty principle',
#   'start': 94.72,
#   'duration': 3.359},
#  {'text': 'situation if i told you you behave',
#   'start': 96.4,
#   'duration': 3.12},
#  {'text': "differently yeah maybe that's what's",
#   'start': 98.079,
#   'duration': 3.201},
#  {'text': 'happening with us of course this is a',
#   'start': 99.52,
#   'duration': 4.0},
#  {'text': 'benchmark from the future where they',
#   'start': 101.28,
#   'duration': 6.56},
#  {'text': 'replay 2022 as a year before ais were',
#   'start': 103.52,
#   'duration': 7.36},
#  {'text': 'good enough yet and now we want to see',
#   'start': 107.84,
#   'duration': 5.919},
#  {'text': 'is it going to pass exactly', 'start': 110.88, 'duration': 4.559},
#  {'text': 'if i was such a', 'start': 113.759, 'duration': 3.36},
#  {'text': 'program would you be able to tell do you',
#   'start': 115.439,
#   'duration': 4.481},
#  {'text': 'think so to the touring test question',
#   'start': 117.119,
#   'duration': 5.921},
#  {'text': "you've talked about", 'start': 119.92, 'duration': 3.12},
#  {'text': 'the benchmark for solving intelligence',
#   'start': 123.2,
#   'duration': 3.919},
#  {'text': 'what would be the impressive thing',
#   'start': 125.68,
#   'duration': 2.96},
#  {'text': "you've talked about winning a nobel",
#   'start': 127.119,
#   'duration': 4.161},
#  {'text': 'prize in a system winning a nobel prize',
#   'start': 128.64,
#   'duration': 4.72},
#  {'text': 'but i still return to the touring test',
#   'start': 131.28,
#   'duration': 3.76},
#  {'text': 'as a compelling test the spirit of the',
#   'start': 133.36,
#   'duration': 3.76},
#  {'text': 'touring test is a compelling test',
#   'start': 135.04,
#   'duration': 3.76},
#  {'text': "yeah the turing test of course it's been",
#   'start': 137.12,
#   'duration': 3.52},
#  {'text': "unbelievably influential and turing's",
#   'start': 138.8,
#   'duration': 4.24},
#  {'text': 'one of my all-time heroes but i think if',
#   'start': 140.64,
#   'duration': 4.239},
#  {'text': 'you look back at the 1950 papers',
#   'start': 143.04,
#   'duration': 3.839},
#  {'text': 'original paper and read the original',
#   'start': 144.879,
#   'duration': 4.0},
#  {'text': "you'll see i don't think he meant it to",
#   'start': 146.879,
#   'duration': 4.321},
#  {'text': 'be a rigorous formal test i think it was',
#   'start': 148.879,
#   'duration': 4.161},
#  {'text': 'more like a thought experiment almost a',
#   'start': 151.2,
#   'duration': 3.52},
#  {'text': 'bit of philosophy he was writing if you',
#   'start': 153.04,
#   'duration': 3.52},
#  {'text': 'look at the style of the paper and you',
#   'start': 154.72,
#   'duration': 3.28},
#  {'text': "can see he didn't specify it very",
#   'start': 156.56,
#   'duration': 3.52},
#  {'text': "rigorously so for example he didn't",
#   'start': 158.0,
#   'duration': 4.879},
#  {'text': 'specify the knowledge that the expert or',
#   'start': 160.08,
#   'duration': 5.439},
#  {'text': 'judge would have um not you know how',
#   'start': 162.879,
#   'duration': 4.801},
#  {'text': 'much time would they have to investigate',
#   'start': 165.519,
#   'duration': 4.0},
#  {'text': 'this so these important parameters if',
#   'start': 167.68,
#   'duration': 4.48},
#  {'text': 'you were gonna make it uh a true sort of',
#   'start': 169.519,
#   'duration': 3.921},
#  {'text': 'formal test', 'start': 172.16, 'duration': 4.32},
#  {'text': 'um and you know some by some measures',
#   'start': 173.44,
#   'duration': 4.879},
#  {'text': 'people claimed the turing test passed',
#   'start': 176.48,
#   'duration': 3.36},
#  {'text': 'several you know a decade ago i remember',
#   'start': 178.319,
#   'duration': 3.2},
#  {'text': 'someone claiming that with a with a kind',
#   'start': 179.84,
#   'duration': 4.56},
#  {'text': 'of very bog standard normal uh',
#   'start': 181.519,
#   'duration': 5.44},
#  {'text': 'logic model um because they pretended it',
#   'start': 184.4,
#   'duration': 5.199},
#  {'text': 'was a it was a kid so the the judges',
#   'start': 186.959,
#   'duration': 4.721},
#  {'text': 'thought that the machine you know was',
#   'start': 189.599,
#   'duration': 5.121},
#  {'text': 'was a was a child so um that would be',
#   'start': 191.68,
#   'duration': 5.52},
#  {'text': 'very different from an expert ai person',
#   'start': 194.72,
#   'duration': 4.32},
#  {'text': 'uh interrogating a machine and knowing',
#   'start': 197.2,
#   'duration': 5.119},
#  {'text': 'how it was built and so on so i think um',
#   'start': 199.04,
#   'duration': 4.64},
#  {'text': 'you know we should probably move away',
#   'start': 202.319,
#   'duration': 4.081},
#  {'text': 'from that as a formal test and move more',
#   'start': 203.68,
#   'duration': 5.839},
#  {'text': 'towards a general test where we test the',
#   'start': 206.4,
#   'duration': 5.759},
#  {'text': 'ai capabilities on a range of tasks and',
#   'start': 209.519,
#   'duration': 5.121},
#  {'text': 'see if it reaches human level or above',
#   'start': 212.159,
#   'duration': 5.121},
#  {'text': 'performance on maybe thousands perhaps',
#   'start': 214.64,
#   'duration': 4.64},
#  {'text': 'even millions of tasks eventually and',
#   'start': 217.28,
#   'duration': 4.56},
#  {'text': 'cover the entire sort of cognitive space',
#   'start': 219.28,
#   'duration': 4.08},
#  {'text': 'so i think', 'start': 221.84, 'duration': 3.119},
#  {'text': 'for its time it was an amazing thought',
#   'start': 223.36,
#   'duration': 3.92},
#  {'text': 'experiment and also 1950s obviously it',
#   'start': 224.959,
#   'duration': 4.321},
#  {'text': 'was barely the dawn of the computer age',
#   'start': 227.28,
#   'duration': 4.08},
#  {'text': 'so of course he only thought about text',
#   'start': 229.28,
#   'duration': 4.239},
#  {'text': 'and now um we have a lot more different',
#   'start': 231.36,
#   'duration': 3.12},
#  {'text': 'inputs', 'start': 233.519, 'duration': 3.44},
#  {'text': 'so yeah maybe the better thing to test',
#   'start': 234.48,
#   'duration': 4.319},
#  {'text': 'is the generalizability so across',
#   'start': 236.959,
#   'duration': 4.0},
#  {'text': "multiple tasks but i think it's also",
#   'start': 238.799,
#   'duration': 5.761},
#  {'text': 'possible as as systems like god show',
#   'start': 240.959,
#   'duration': 4.56},
#  {'text': 'that', 'start': 244.56, 'duration': 2.879},
#  {'text': 'eventually that might map right back to',
#   'start': 245.519,
#   'duration': 3.681},
#  {'text': 'language so you might be able to',
#   'start': 247.439,
#   'duration': 4.08},
#  {'text': 'demonstrate your ability to generalize',
#   'start': 249.2,
#   'duration': 3.92},
#  {'text': 'across tasks', 'start': 251.519, 'duration': 3.841},
#  {'text': 'by then communicating your ability to',
#   'start': 253.12,
#   'duration': 4.399},
#  {'text': 'generalize across tasks which is kind of',
#   'start': 255.36,
#   'duration': 3.68},
#  {'text': 'what we do through conversation anyway',
#   'start': 257.519,
#   'duration': 3.201},
#  {'text': 'when we jump around', 'start': 259.04, 'duration': 3.52},
#  {'text': "ultimately what's in there in that",
#   'start': 260.72,
#   'duration': 4.24},
#  {'text': 'conversation is not just you moving',
#   'start': 262.56,
#   'duration': 4.32},
#  {'text': 'around knowledge', 'start': 264.96, 'duration': 4.16},
#  {'text': "it's you moving around like these",
#   'start': 266.88,
#   'duration': 4.879},
#  {'text': 'entirely different modalities of',
#   'start': 269.12,
#   'duration': 5.84},
#  {'text': 'understanding that ultimately map to',
#   'start': 271.759,
#   'duration': 5.121},
#  {'text': 'your ability to', 'start': 274.96, 'duration': 4.48},
#  {'text': 'to uh operate successfully in all these',
#   'start': 276.88,
#   'duration': 5.599},
#  {'text': 'domains which you can think of as tasks',
#   'start': 279.44,
#   'duration': 5.52},
#  {'text': 'yeah i think certainly we as humans use',
#   'start': 282.479,
#   'duration': 4.961},
#  {'text': 'language as our main generalization',
#   'start': 284.96,
#   'duration': 5.04},
#  {'text': 'communication tool so i think we end up',
#   'start': 287.44,
#   'duration': 4.88},
#  {'text': 'thinking in language and expressing our',
#   'start': 290.0,
#   'duration': 4.96},
#  {'text': "solutions in language um so it's going",
#   'start': 292.32,
#   'duration': 4.08},
#  {'text': 'to be very powerful', 'start': 294.96, 'duration': 5.12},
#  {'text': 'uh uh mode in which to uh explain you',
#   'start': 296.4,
#   'duration': 5.2},
#  {'text': "know the system to explain what it's",
#   'start': 300.08,
#   'duration': 4.8},
#  {'text': "doing um but i don't think it's the only",
#   'start': 301.6,
#   'duration': 6.56},
#  {'text': 'uh uh modality that matters so i think',
#   'start': 304.88,
#   'duration': 4.72},
#  {'text': "there's gonna be a lot of you know",
#   'start': 308.16,
#   'duration': 2.72},
#  {'text': "there's there's a lot of different ways",
#   'start': 309.6,
#   'duration': 4.24},
#  {'text': 'to express uh capabilities uh other than',
#   'start': 310.88,
#   'duration': 4.56},
#  {'text': 'just language', 'start': 313.84, 'duration': 2.88},
#  {'text': 'yeah visual', 'start': 315.44, 'duration': 4.479},
#  {'text': 'robotics body language', 'start': 316.72, 'duration': 4.319},
#  {'text': 'um', 'start': 319.919, 'duration': 3.041},
#  {'text': 'yeah action is the interactive aspect of',
#   'start': 321.039,
#   'duration': 3.761},
#  {'text': "all that that's all part of it but",
#   'start': 322.96,
#   'duration': 3.28},
#  {'text': "what's interesting with gato is that",
#   'start': 324.8,
#   'duration': 4.08},
#  {'text': "it's a it's it's it's sort of pushing",
#   'start': 326.24,
#   'duration': 4.48},
#  {'text': 'prediction to the maximum in terms of',
#   'start': 328.88,
#   'duration': 3.84},
#  {'text': 'like you know mapping arbitrary',
#   'start': 330.72,
#   'duration': 4.08},
#  {'text': 'sequences to other sequences and sort of',
#   'start': 332.72,
#   'duration': 3.36},
#  {'text': "just predicting what's going to happen",
#   'start': 334.8,
#   'duration': 3.839},
#  {'text': 'next so prediction seems to be', 'start': 336.08, 'duration': 4.88},
#  {'text': 'fundamental to intelligence', 'start': 338.639, 'duration': 4.161},
#  {'text': "and what you're predicting", 'start': 340.96, 'duration': 4.0},
#  {'text': "doesn't so much matter yeah it seems",
#   'start': 342.8,
#   'duration': 3.839},
#  {'text': 'like you can generalize that quite well',
#   'start': 344.96,
#   'duration': 3.28},
#  {'text': 'so obviously language models predict the',
#   'start': 346.639,
#   'duration': 4.241},
#  {'text': 'next word um gato predicts potentially',
#   'start': 348.24,
#   'duration': 6.0},
#  {'text': "any uh action or any token uh and it's",
#   'start': 350.88,
#   'duration': 4.72},
#  {'text': "just the beginning really it's our most",
#   'start': 354.24,
#   'duration': 3.76},
#  {'text': 'general agent one could call it so far',
#   'start': 355.6,
#   'duration': 4.4},
#  {'text': 'but um you know that itself can be',
#   'start': 358.0,
#   'duration': 3.6},
#  {'text': "scaled up massively more than we've done",
#   'start': 360.0,
#   'duration': 3.039},
#  {'text': "so far obviously we're in the in the",
#   'start': 361.6,
#   'duration': 4.08},
#  {'text': 'middle of doing that but the big part of',
#   'start': 363.039,
#   'duration': 6.081},
#  {'text': 'solving agi is creating benchmarks that',
#   'start': 365.68,
#   'duration': 6.48},
#  {'text': 'help us get closer and closer sort of',
#   'start': 369.12,
#   'duration': 4.799},
#  {'text': 'creating benchmarks that test the',
#   'start': 372.16,
#   'duration': 3.599},
#  {'text': "journalizability and it's just still",
#   'start': 373.919,
#   'duration': 4.881},
#  {'text': 'interesting that this fella alan turing',
#   'start': 375.759,
#   'duration': 5.601},
#  {'text': 'was one of the first and probably still',
#   'start': 378.8,
#   'duration': 4.959},
#  {'text': 'one of the only people that was trying',
#   'start': 381.36,
#   'duration': 4.24},
#  {'text': 'maybe philosophically but was trying to',
#   'start': 383.759,
#   'duration': 3.44},
#  {'text': 'formulate a benchmark that could be',
#   'start': 385.6,
#   'duration': 3.2},
#  {'text': 'followed it is', 'start': 387.199, 'duration': 4.081},
#  {'text': "even though it's it's fuzzy it's still",
#   'start': 388.8,
#   'duration': 4.08},
#  {'text': 'sufficiently rigorous to where you can',
#   'start': 391.28,
#   'duration': 3.84},
#  {'text': 'run that test and i still think',
#   'start': 392.88,
#   'duration': 4.159},
#  {'text': 'something like the touring test will at',
#   'start': 395.12,
#   'duration': 3.519},
#  {'text': 'the end of the day', 'start': 397.039, 'duration': 3.361},
#  {'text': 'be the thing that truly', 'start': 398.639, 'duration': 3.84},
#  {'text': 'impresses other humans', 'start': 400.4, 'duration': 4.239},
#  {'text': 'so that you can have a close friend',
#   'start': 402.479,
#   'duration': 3.921},
#  {'text': "who's an ai system", 'start': 404.639, 'duration': 3.601},
#  {'text': 'for that friend to be a good friend',
#   'start': 406.4,
#   'duration': 4.0},
#  {'text': "they're going to have to be able to",
#   'start': 408.24,
#   'duration': 4.799},
#  {'text': 'uh play starcraft', 'start': 410.4, 'duration': 4.239},
#  {'text': "and they're going to have to do all of",
#   'start': 413.039,
#   'duration': 5.041},
#  {'text': 'these tasks um get you a beer so the',
#   'start': 414.639,
#   'duration': 5.28},
#  {'text': 'robotics tasks', 'start': 418.08, 'duration': 5.04},
#  {'text': 'uh play games with you use language',
#   'start': 419.919,
#   'duration': 5.84},
#  {'text': 'humor all those kinds of things but that',
#   'start': 423.12,
#   'duration': 4.799},
#  {'text': 'ultimately can boil down to language it',
#   'start': 425.759,
#   'duration': 4.401},
#  {'text': 'feels like not in terms of the ai',
#   'start': 427.919,
#   'duration': 4.56},
#  {'text': 'community but in terms of the actual',
#   'start': 430.16,
#   'duration': 4.159},
#  {'text': 'impact of general intelligence on the',
#   'start': 432.479,
#   'duration': 3.681},
#  {'text': 'world it feels like language will be the',
#   'start': 434.319,
#   'duration': 4.641},
#  {'text': 'place where it truly shines i think so',
#   'start': 436.16,
#   'duration': 4.72},
#  {'text': "because it's such an important kind of",
#   'start': 438.96,
#   'duration': 4.079},
#  {'text': "input output for us i think you're right",
#   'start': 440.88,
#   'duration': 4.0},
#  {'text': 'i think the turing test that what the',
#   'start': 443.039,
#   'duration': 4.241},
#  {'text': 'the kind of the the philosophy behind it',
#   'start': 444.88,
#   'duration': 5.36},
#  {'text': 'which is the idea of can can a machine',
#   'start': 447.28,
#   'duration': 7.6},
#  {'text': 'mimic the behaviors of a human and men',
#   'start': 450.24,
#   'duration': 6.799},
#  {'text': 'and i would say wider than just language',
#   'start': 454.88,
#   'duration': 3.759},
#  {'text': 'and text', 'start': 457.039, 'duration': 3.521},
#  {'text': 'then you know in terms of actions and',
#   'start': 458.639,
#   'duration': 3.601},
#  {'text': 'everything else creativity all these',
#   'start': 460.56,
#   'duration': 4.079},
#  {'text': 'things then um if it can sort of match',
#   'start': 462.24,
#   'duration': 5.04},
#  {'text': 'or exceed human cognitive capabilities',
#   'start': 464.639,
#   'duration': 4.481},
#  {'text': 'then i think we have a you know true',
#   'start': 467.28,
#   'duration': 3.44},
#  {'text': 'intelligence so i thought from that',
#   'start': 469.12,
#   'duration': 3.359},
#  {'text': "perspective you're right i think he did",
#   'start': 470.72,
#   'duration': 5.12},
#  {'text': 'formulate the right uh kind of uh setup',
#   'start': 472.479,
#   'duration': 5.361},
#  {'text': "i just i think there'll be a kind of",
#   'start': 475.84,
#   'duration': 3.359},
#  {'text': 'humor', 'start': 477.84, 'duration': 3.28},
#  {'text': 'in the ai systems of the future looking',
#   'start': 479.199,
#   'duration': 4.241},
#  {'text': 'back to this conversation', 'start': 481.12, 'duration': 4.88},
#  {'text': 'and thinking about the touring test',
#   'start': 483.44,
#   'duration': 5.12},
#  {'text': 'and uh also thinking about', 'start': 486.0, 'duration': 4.319},
#  {'text': 'by that time they would know which year',
#   'start': 488.56,
#   'duration': 4.639},
#  {'text': 'they were finally able to sort of cross',
#   'start': 490.319,
#   'duration': 4.241},
#  {'text': 'the threshold of human level', 'start': 493.199, 'duration': 3.921},
#  {'text': 'intelligence and think', 'start': 494.56, 'duration': 4.319},
#  {'text': 'how funny it is that we humans were',
#   'start': 497.12,
#   'duration': 2.72},
#  {'text': 'still', 'start': 498.879, 'duration': 3.44},
#  {'text': 'confused about this whole problem',
#   'start': 499.84,
#   'duration': 4.72},
#  {'text': 'that has been long ago been solved',
#   'start': 502.319,
#   'duration': 4.0},
#  {'text': 'well hello to the ai agents of the',
#   'start': 504.56,
#   'duration': 4.8},
#  {'text': 'future anyway so going back to your',
#   'start': 506.319,
#   'duration': 4.961},
#  {'text': 'to your journey when did you fall in',
#   'start': 509.36,
#   'duration': 4.239},
#  {'text': 'love with programming first', 'start': 511.28, 'duration': 4.16},
#  {'text': "well it's pretty uh pretty young age",
#   'start': 513.599,
#   'duration': 3.761},
#  {'text': 'actually so um', 'start': 515.44, 'duration': 4.399},
#  {'text': 'you know i started off uh actually games',
#   'start': 517.36,
#   'duration': 4.479},
#  {'text': 'was my first love so starting to play',
#   'start': 519.839,
#   'duration': 3.76},
#  {'text': 'chess when i was around four years old',
#   'start': 521.839,
#   'duration': 3.761},
#  {'text': 'and then um it was actually with',
#   'start': 523.599,
#   'duration': 4.321},
#  {'text': 'winnings from a chess competition that i',
#   'start': 525.6,
#   'duration': 4.0},
#  {'text': 'managed to buy my first chess computer',
#   'start': 527.92,
#   'duration': 2.88},
#  {'text': 'when i was about eight years old it was',
#   'start': 529.6,
#   'duration': 3.44},
#  {'text': 'a zx spectrum which was hugely popular',
#   'start': 530.8,
#   'duration': 3.84},
#  {'text': 'in the uk at the time', 'start': 533.04, 'duration': 4.32},
#  {'text': "and uh it's amazing machine because i",
#   'start': 534.64,
#   'duration': 4.639},
#  {'text': 'think it trained a whole generation of',
#   'start': 537.36,
#   'duration': 4.08},
#  {'text': 'programmers in the uk because it was so',
#   'start': 539.279,
#   'duration': 3.761},
#  {'text': 'accessible you know you literally',
#   'start': 541.44,
#   'duration': 3.12},
#  {'text': 'switched it on and there was the basic',
#   'start': 543.04,
#   'duration': 4.0},
#  {'text': 'prompt and you could just get going and',
#   'start': 544.56,
#   'duration': 4.24},
#  {'text': "um my parents didn't really know",
#   'start': 547.04,
#   'duration': 3.6},
#  {'text': 'anything about computers so but because',
#   'start': 548.8,
#   'duration': 3.68},
#  {'text': 'it was my money from a chess competition',
#   'start': 550.64,
#   'duration': 4.48},
#  {'text': 'i could i could say i i wanted to buy it',
#   'start': 552.48,
#   'duration': 4.479},
#  {'text': 'uh and then you know i just went to',
#   'start': 555.12,
#   'duration': 5.04},
#  {'text': 'bookstores got books on programming and',
#   'start': 556.959,
#   'duration': 5.601},
#  {'text': 'um started typing in you know the',
#   'start': 560.16,
#   'duration': 4.72},
#  {'text': 'programming code and and then of course',
#   'start': 562.56,
#   'duration': 4.08},
#  {'text': 'um once you start doing that you start',
#   'start': 564.88,
#   'duration': 3.28},
#  {'text': 'adjusting it and then making your own',
#   'start': 566.64,
#   'duration': 3.44},
#  {'text': "games and that's when i fell in love",
#   'start': 568.16,
#   'duration': 3.359},
#  {'text': 'with computers and realized that they',
#   'start': 570.08,
#   'duration': 5.12},
#  {'text': 'were a very magical device um in a way i',
#   'start': 571.519,
#   'duration': 4.88},
#  {'text': 'kind of i would have been able to',
#   'start': 575.2,
#   'duration': 2.72},
#  {'text': 'explain this at the time but i felt that',
#   'start': 576.399,
#   'duration': 3.041},
#  {'text': 'they were sort of almost a magical',
#   'start': 577.92,
#   'duration': 3.76},
#  {'text': 'extension of your mind i always had this',
#   'start': 579.44,
#   'duration': 3.76},
#  {'text': "feeling and i've always loved this about",
#   'start': 581.68,
#   'duration': 3.36},
#  {'text': 'computers that you can set them off',
#   'start': 583.2,
#   'duration': 4.24},
#  {'text': 'doing something some task for you you',
#   'start': 585.04,
#   'duration': 4.32},
#  {'text': 'can go to sleep come back the next day',
#   'start': 587.44,
#   'duration': 2.959},
#  {'text': "and it's solved", 'start': 589.36, 'duration': 3.84},
#  {'text': 'um you know that feels magical to me so',
#   'start': 590.399,
#   'duration': 4.401},
#  {'text': 'i mean all machines do that to some',
#   'start': 593.2,
#   'duration': 3.68},
#  {'text': 'extent they all enhance our natural',
#   'start': 594.8,
#   'duration': 3.84},
#  {'text': 'capabilities obviously cars make us',
#   'start': 596.88,
#   'duration': 4.16},
#  {'text': 'allow us to move faster than we can run',
#   'start': 598.64,
#   'duration': 4.879},
#  {'text': 'but this was a machine to extend the',
#   'start': 601.04,
#   'duration': 3.359},
#  {'text': 'mind', 'start': 603.519, 'duration': 3.601},
#  {'text': 'and and then of course ai is the',
#   'start': 604.399,
#   'duration': 4.88},
#  {'text': 'ultimate expression of what a machine',
#   'start': 607.12,
#   'duration': 4.959},
#  {'text': 'may be able to do or learn so',
#   'start': 609.279,
#   'duration': 4.641},
#  {'text': 'very naturally for me that thought',
#   'start': 612.079,
#   'duration': 3.841},
#  {'text': 'extended into into ai quite quickly',
#   'start': 613.92,
#   'duration': 4.479},
#  {'text': 'remember the the programming language',
#   'start': 615.92,
#   'duration': 3.84},
#  {'text': 'that was first', 'start': 618.399, 'duration': 2.641},
#  {'text': 'started', 'start': 619.76, 'duration': 2.72},
#  {'text': 'special to the machine no it was just',
#   'start': 621.04,
#   'duration': 2.96},
#  {'text': 'the base it was just i think it was just',
#   'start': 622.48,
#   'duration': 3.599},
#  {'text': "basic uh on the zx spectrum i don't know",
#   'start': 624.0,
#   'duration': 3.92},
#  {'text': 'what specific form it was and then later',
#   'start': 626.079,
#   'duration': 5.041},
#  {'text': 'on i got a commodore amiga which uh',
#   'start': 627.92,
#   'duration': 5.2},
#  {'text': "was a fantastic machine no you're just",
#   'start': 631.12,
#   'duration': 3.92},
#  {'text': 'showing off so yeah well lots of my',
#   'start': 633.12,
#   'duration': 4.0},
#  {'text': "friends had atari st's and i i managed",
#   'start': 635.04,
#   'duration': 3.76},
#  {'text': 'to get amigas it was a bit more powerful',
#   'start': 637.12,
#   'duration': 3.839},
#  {'text': 'and uh and that was incredible and used',
#   'start': 638.8,
#   'duration': 5.2},
#  {'text': 'to do um programming in assembler and',
#   'start': 640.959,
#   'duration': 5.921},
#  {'text': 'and uh also amos basic this this',
#   'start': 644.0,
#   'duration': 4.64},
#  {'text': 'specific form of basic it was incredible',
#   'start': 646.88,
#   'duration': 4.0},
#  {'text': 'actually as well all my coding skills',
#   'start': 648.64,
#   'duration': 4.48},
#  {'text': 'and when did you fall in love with ai so',
#   'start': 650.88,
#   'duration': 4.56},
#  {'text': 'when did you first', 'start': 653.12, 'duration': 3.92},
#  {'text': 'start to gain an understanding that you',
#   'start': 655.44,
#   'duration': 4.079},
#  {'text': 'can not just write programs that',
#   'start': 657.04,
#   'duration': 4.479},
#  {'text': 'do some mathematical operations for you',
#   'start': 659.519,
#   'duration': 4.961},
#  {'text': "while you sleep but something that's",
#   'start': 661.519,
#   'duration': 4.88},
#  {'text': 'a keen to', 'start': 664.48, 'duration': 4.24},
#  {'text': 'bringing an entity to life', 'start': 666.399, 'duration': 3.201},
#  {'text': 'sort of', 'start': 668.72, 'duration': 3.04},
#  {'text': 'a thing that can figure out something',
#   'start': 669.6,
#   'duration': 4.16},
#  {'text': 'more complicated than uh', 'start': 671.76, 'duration': 4.0},
#  {'text': 'than a simple mathematical operation',
#   'start': 673.76,
#   'duration': 3.759},
#  {'text': 'yeah so there was a few stages for me',
#   'start': 675.76,
#   'duration': 4.16},
#  {'text': 'all while i was very young so first of',
#   'start': 677.519,
#   'duration': 4.241},
#  {'text': 'all as i was trying to improve at',
#   'start': 679.92,
#   'duration': 3.44},
#  {'text': 'playing chess i was captaining various',
#   'start': 681.76,
#   'duration': 3.199},
#  {'text': 'england junior chess teams and at the',
#   'start': 683.36,
#   'duration': 3.28},
#  {'text': 'time when i was about you know maybe 10',
#   'start': 684.959,
#   'duration': 3.44},
#  {'text': '11 years old i was gonna become a',
#   'start': 686.64,
#   'duration': 3.12},
#  {'text': 'professional chess player that was my',
#   'start': 688.399,
#   'duration': 2.241},
#  {'text': 'first', 'start': 689.76, 'duration': 4.319},
#  {'text': 'thought um that dream was there sure she',
#   'start': 690.64,
#   'duration': 5.04},
#  {'text': 'tried to get to the highest level yeah',
#   'start': 694.079,
#   'duration': 4.241},
#  {'text': 'so i was um you know i got to when i was',
#   'start': 695.68,
#   'duration': 4.32},
#  {'text': 'about 12 years old i got to master stand',
#   'start': 698.32,
#   'duration': 3.199},
#  {'text': 'and i was second highest rated player in',
#   'start': 700.0,
#   'duration': 3.279},
#  {'text': 'the world to judith polgar who obviously',
#   'start': 701.519,
#   'duration': 4.161},
#  {'text': 'ended up being an amazing chess player',
#   'start': 703.279,
#   'duration': 6.161},
#  {'text': "and uh world women's champion and when i",
#   'start': 705.68,
#   'duration': 5.2},
#  {'text': 'was trying to improve at chess where you',
#   'start': 709.44,
#   'duration': 2.959},
#  {'text': 'know what you do is you obviously first',
#   'start': 710.88,
#   'duration': 2.88},
#  {'text': "of all you're trying to improve your own",
#   'start': 712.399,
#   'duration': 4.56},
#  {'text': 'thinking processes so that leads you to',
#   'start': 713.76,
#   'duration': 4.72},
#  {'text': 'thinking about thinking how is your',
#   'start': 716.959,
#   'duration': 3.601},
#  {'text': 'brain coming up with these ideas why is',
#   'start': 718.48,
#   'duration': 4.479},
#  {'text': 'it making mistakes how can you how can',
#   'start': 720.56,
#   'duration': 4.16},
#  {'text': 'you improve that thought process but the',
#   'start': 722.959,
#   'duration': 3.921},
#  {'text': 'second thing is that you it was just the',
#   'start': 724.72,
#   'duration': 4.239},
#  {'text': 'beginning this was like in the in the',
#   'start': 726.88,
#   'duration': 4.399},
#  {'text': 'early 80s mid 80s of chess computers if',
#   'start': 728.959,
#   'duration': 3.68},
#  {'text': 'you remember they were physical boards',
#   'start': 731.279,
#   'duration': 2.881},
#  {'text': 'like the one we have in front of us and',
#   'start': 732.639,
#   'duration': 3.361},
#  {'text': 'you pressed down the you know the',
#   'start': 734.16,
#   'duration': 4.16},
#  {'text': 'squares and i think kasparov had a',
#   'start': 736.0,
#   'duration': 5.279},
#  {'text': 'branded version of it that i i i got and',
#   'start': 738.32,
#   'duration': 5.04},
#  {'text': "um you were you know used to they're not",
#   'start': 741.279,
#   'duration': 3.521},
#  {'text': 'as strong as they are today but they',
#   'start': 743.36,
#   'duration': 3.2},
#  {'text': 'were they were pretty strong and you',
#   'start': 744.8,
#   'duration': 4.4},
#  {'text': 'used to practice against them um to try',
#   'start': 746.56,
#   'duration': 4.24},
#  {'text': 'and improve your openings and other',
#   'start': 749.2,
#   'duration': 3.199},
#  {'text': 'things and so i remember i think i',
#   'start': 750.8,
#   'duration': 2.88},
#  {'text': 'probably got my first one i was around',
#   'start': 752.399,
#   'duration': 4.161},
#  {'text': '11 or 12. and i remember thinking um',
#   'start': 753.68,
#   'duration': 4.32},
#  {'text': 'this is amazing you know how how has',
#   'start': 756.56,
#   'duration': 4.32},
#  {'text': 'someone programmed uh uh this this chess',
#   'start': 758.0,
#   'duration': 5.76},
#  {'text': 'board to play chess uh and uh it was',
#   'start': 760.88,
#   'duration': 4.959},
#  {'text': 'very formative book i bought which was',
#   'start': 763.76,
#   'duration': 4.079},
#  {'text': 'called the chess computer handbook by',
#   'start': 765.839,
#   'duration': 4.481},
#  {'text': 'david levy which came out in 1984 or',
#   'start': 767.839,
#   'duration': 3.521},
#  {'text': 'something so i must have got it when i',
#   'start': 770.32,
#   'duration': 3.84},
#  {'text': 'was about 11 12 and it explained fully',
#   'start': 771.36,
#   'duration': 4.8},
#  {'text': 'how these chess programs were made i',
#   'start': 774.16,
#   'duration': 4.72},
#  {'text': 'remember my first ai program being uh',
#   'start': 776.16,
#   'duration': 5.119},
#  {'text': "programming my amiga it couldn't it",
#   'start': 778.88,
#   'duration': 4.0},
#  {'text': "wasn't powerful enough to play chess i",
#   'start': 781.279,
#   'duration': 2.961},
#  {'text': "couldn't write a whole chess program but",
#   'start': 782.88,
#   'duration': 3.84},
#  {'text': 'i wrote a program for it to play othello',
#   'start': 784.24,
#   'duration': 4.0},
#  {'text': "reversey it's sometimes called i think",
#   'start': 786.72,
#   'duration': 3.919},
#  {'text': 'in the u.s and so a slightly simpler',
#   'start': 788.24,
#   'duration': 4.32},
#  {'text': 'game than chess but i used all of the',
#   'start': 790.639,
#   'duration': 3.841},
#  {'text': 'principles that chess programs had alpha',
#   'start': 792.56,
#   'duration': 3.92},
#  {'text': 'beta search all of that and that was my',
#   'start': 794.48,
#   'duration': 3.28},
#  {'text': 'first ai program i remember that very',
#   'start': 796.48,
#   'duration': 3.2},
#  {'text': 'well was around 12 years old so that',
#   'start': 797.76,
#   'duration': 4.079},
#  {'text': 'that that brought me into ai and then',
#   'start': 799.68,
#   'duration': 4.56},
#  {'text': 'the second part was later on uh when i',
#   'start': 801.839,
#   'duration': 4.721},
#  {'text': 'was around 1617 and i was writing games',
#   'start': 804.24,
#   'duration': 4.48},
#  {'text': 'professionally designing games uh',
#   'start': 806.56,
#   'duration': 4.32},
#  {'text': 'writing a game called theme park which',
#   'start': 808.72,
#   'duration': 5.2},
#  {'text': 'um had ai as a core gameplay component',
#   'start': 810.88,
#   'duration': 5.92},
#  {'text': 'as part of the simulation um and it sold',
#   'start': 813.92,
#   'duration': 4.159},
#  {'text': 'you know millions of copies around the',
#   'start': 816.8,
#   'duration': 3.44},
#  {'text': 'world and people loved the way that the',
#   'start': 818.079,
#   'duration': 4.081},
#  {'text': 'ai even though it was relatively simple',
#   'start': 820.24,
#   'duration': 4.8},
#  {'text': "by today's ai standards um was was",
#   'start': 822.16,
#   'duration': 4.479},
#  {'text': 'reacting to the way you as the player',
#   'start': 825.04,
#   'duration': 3.76},
#  {'text': 'played it so it was called a sandbox',
#   'start': 826.639,
#   'duration': 3.921},
#  {'text': "game so it's one of the first types of",
#   'start': 828.8,
#   'duration': 4.159},
#  {'text': 'games like that along with simcity and',
#   'start': 830.56,
#   'duration': 4.0},
#  {'text': 'it meant that every game you played was',
#   'start': 832.959,
#   'duration': 2.641},
#  {'text': 'unique', 'start': 834.56, 'duration': 2.8},
#  {'text': 'is there something you could say just on',
#   'start': 835.6,
#   'duration': 3.2},
#  {'text': 'a small tangent', 'start': 837.36, 'duration': 2.4},
#  {'text': 'about', 'start': 838.8, 'duration': 5.36},
#  {'text': 'really impressive ai from a game design',
#   'start': 839.76,
#   'duration': 6.8},
#  {'text': 'human enjoyment perspective', 'start': 844.16, 'duration': 4.72},
#  {'text': "really impressive ai that you've seen in",
#   'start': 846.56,
#   'duration': 4.48},
#  {'text': 'games and maybe what does it take to',
#   'start': 848.88,
#   'duration': 4.319},
#  {'text': 'create ai system and how hard of a',
#   'start': 851.04,
#   'duration': 5.039},
#  {'text': 'problem is that so a million questions',
#   'start': 853.199,
#   'duration': 5.041},
#  {'text': 'just as a brief tangent', 'start': 856.079, 'duration': 4.161},
#  {'text': 'well look i think um', 'start': 858.24, 'duration': 4.32},
#  {'text': 'games uh games have been significant in',
#   'start': 860.24,
#   'duration': 3.92},
#  {'text': 'my life for three reasons so first of',
#   'start': 862.56,
#   'duration': 3.519},
#  {'text': 'all to to i was playing them and',
#   'start': 864.16,
#   'duration': 3.919},
#  {'text': 'training myself on games when i was a',
#   'start': 866.079,
#   'duration': 4.241},
#  {'text': 'kid then i went through a phase of',
#   'start': 868.079,
#   'duration': 4.88},
#  {'text': 'designing games and writing ai4 games so',
#   'start': 870.32,
#   'duration': 4.959},
#  {'text': 'all the games i i professionally wrote',
#   'start': 872.959,
#   'duration': 4.801},
#  {'text': 'uh had ai as a core component and that',
#   'start': 875.279,
#   'duration': 5.521},
#  {'text': 'was mostly in the in the 90s and the',
#   'start': 877.76,
#   'duration': 4.639},
#  {'text': 'reason i was doing that in games',
#   'start': 880.8,
#   'duration': 3.599},
#  {'text': 'industry was at the time the games',
#   'start': 882.399,
#   'duration': 3.761},
#  {'text': 'industry i think was the cutting edge of',
#   'start': 884.399,
#   'duration': 4.0},
#  {'text': 'technology so whether it was graphics',
#   'start': 886.16,
#   'duration': 4.16},
#  {'text': 'with people like john carmack and quake',
#   'start': 888.399,
#   'duration': 5.281},
#  {'text': 'and those kind of things or ai i think',
#   'start': 890.32,
#   'duration': 5.04},
#  {'text': 'actually all the action was going on in',
#   'start': 893.68,
#   'duration': 3.599},
#  {'text': "games and and we've seen we're still",
#   'start': 895.36,
#   'duration': 3.36},
#  {'text': 'reaping the benefits of that even with',
#   'start': 897.279,
#   'duration': 3.68},
#  {'text': 'things like gpus which you know i find',
#   'start': 898.72,
#   'duration': 3.6},
#  {'text': 'ironic was obviously invented for',
#   'start': 900.959,
#   'duration': 2.961},
#  {'text': 'graphics computer graphics but then',
#   'start': 902.32,
#   'duration': 3.759},
#  {'text': 'turns out to be amazingly useful for ai',
#   'start': 903.92,
#   'duration': 3.68},
#  {'text': "it just turns out everything's a matrix",
#   'start': 906.079,
#   'duration': 3.76},
#  {'text': 'multiplication it appears you know in',
#   'start': 907.6,
#   'duration': 3.44},
#  {'text': 'the whole world', 'start': 909.839, 'duration': 4.24},
#  {'text': 'so um so i think games at the time had',
#   'start': 911.04,
#   'duration': 5.12},
#  {'text': 'the most cutting edge ai and a lot of',
#   'start': 914.079,
#   'duration': 4.721},
#  {'text': 'the the games uh uh we you know i was',
#   'start': 916.16,
#   'duration': 4.08},
#  {'text': 'involved in writing so there was a game',
#   'start': 918.8,
#   'duration': 2.8},
#  {'text': 'called black and white which was one',
#   'start': 920.24,
#   'duration': 2.8},
#  {'text': 'game i was involved with in the early',
#   'start': 921.6,
#   'duration': 3.919},
#  {'text': 'stages of which i still think is the',
#   'start': 923.04,
#   'duration': 3.76},
#  {'text': 'most um', 'start': 925.519, 'duration': 3.44},
#  {'text': 'impressive uh example of reinforcement',
#   'start': 926.8,
#   'duration': 4.24},
#  {'text': 'learning in a computer game so in that',
#   'start': 928.959,
#   'duration': 3.921},
#  {'text': 'game you know you trained a little pet',
#   'start': 931.04,
#   'duration': 4.159},
#  {'text': 'animal uh and', 'start': 932.88, 'duration': 4.0},
#  {'text': 'yeah and it sort of learned from how you',
#   'start': 935.199,
#   'duration': 3.2},
#  {'text': 'were treating it so if you treated it',
#   'start': 936.88,
#   'duration': 4.0},
#  {'text': 'badly then it became mean yeah and then',
#   'start': 938.399,
#   'duration': 4.401},
#  {'text': 'it would be mean to to your villagers',
#   'start': 940.88,
#   'duration': 3.6},
#  {'text': 'and your and your population the sort of',
#   'start': 942.8,
#   'duration': 3.2},
#  {'text': 'uh the little tribe that you were',
#   'start': 944.48,
#   'duration': 3.52},
#  {'text': 'running uh but if you were kind to it',
#   'start': 946.0,
#   'duration': 3.68},
#  {'text': 'then it would be kind and people were',
#   'start': 948.0,
#   'duration': 3.759},
#  {'text': 'fascinated by how that was and so was i',
#   'start': 949.68,
#   'duration': 3.519},
#  {'text': 'to be honest with the way it kind of',
#   'start': 951.759,
#   'duration': 4.08},
#  {'text': 'developed and um especially the mapping',
#   'start': 953.199,
#   'duration': 4.961},
#  {'text': 'to good and evil yeah it made you made',
#   'start': 955.839,
#   'duration': 5.281},
#  {'text': 'you realize made me realize that you can',
#   'start': 958.16,
#   'duration': 4.96},
#  {'text': 'sort of in the way in the choices you',
#   'start': 961.12,
#   'duration': 4.0},
#  {'text': 'make can define', 'start': 963.12, 'duration': 3.04},
#  {'text': 'uh the', 'start': 965.12, 'duration': 4.079},
#  {'text': 'where you end up and that means',
#   'start': 966.16,
#   'duration': 5.52},
#  {'text': 'all of us are capable of the good',
#   'start': 969.199,
#   'duration': 5.281},
#  {'text': 'uh evil it all matters in uh the',
#   'start': 971.68,
#   'duration': 4.719},
#  {'text': 'different choices along the trajectory',
#   'start': 974.48,
#   'duration': 3.76},
#  {'text': "to those places that you make it's",
#   'start': 976.399,
#   'duration': 3.921},
#  {'text': 'fascinating i mean games can do that',
#   'start': 978.24,
#   'duration': 3.68},
#  {'text': "philosophically to you and it's rare it",
#   'start': 980.32,
#   'duration': 3.519},
#  {'text': 'seems rare yeah well games are i think a',
#   'start': 981.92,
#   'duration': 4.24},
#  {'text': 'unique medium because um you as the',
#   'start': 983.839,
#   'duration': 3.601},
#  {'text': "player you're not just passively",
#   'start': 986.16,
#   'duration': 4.08},
#  {'text': 'consuming the the entertainment right',
#   'start': 987.44,
#   'duration': 5.28},
#  {'text': "you're actually actively involved as an",
#   'start': 990.24,
#   'duration': 4.88},
#  {'text': "as a as an agent so i think that's what",
#   'start': 992.72,
#   'duration': 3.84},
#  {'text': 'makes it in some ways can be more',
#   'start': 995.12,
#   'duration': 3.36},
#  {'text': 'visceral than other other mediums like',
#   'start': 996.56,
#   'duration': 3.839},
#  {'text': 'you know films and books so the second',
#   'start': 998.48,
#   'duration': 3.68},
#  {'text': 'so that was you know designing ai and',
#   'start': 1000.399,
#   'duration': 4.961},
#  {'text': "games and then the third use uh uh i've",
#   'start': 1002.16,
#   'duration': 5.44},
#  {'text': "we've used of ai is in deep mind from",
#   'start': 1005.36,
#   'duration': 4.399},
#  {'text': 'the beginning which is using games as a',
#   'start': 1007.6,
#   'duration': 5.12},
#  {'text': 'testing ground for proving out ai',
#   'start': 1009.759,
#   'duration': 5.121},
#  {'text': 'algorithms and developing ai algorithms',
#   'start': 1012.72,
#   'duration': 4.88},
#  {'text': 'and that was a that was a sort of um a',
#   'start': 1014.88,
#   'duration': 4.319},
#  {'text': 'core component of our vision at the',
#   'start': 1017.6,
#   'duration': 3.44},
#  {'text': 'start of deepmind was that we would use',
#   'start': 1019.199,
#   'duration': 4.721},
#  {'text': 'games very heavily uh as our main',
#   'start': 1021.04,
#   'duration': 4.879},
#  {'text': 'testing ground certainly to begin with',
#   'start': 1023.92,
#   'duration': 3.84},
#  {'text': "um because it's super efficient to use",
#   'start': 1025.919,
#   'duration': 4.321},
#  {'text': "games and also you know it's very easy",
#   'start': 1027.76,
#   'duration': 5.039},
#  {'text': 'to have metrics to see how well your',
#   'start': 1030.24,
#   'duration': 4.559},
#  {'text': 'systems are improving and what direction',
#   'start': 1032.799,
#   'duration': 3.28},
#  {'text': 'your ideas are going in and whether',
#   'start': 1034.799,
#   'duration': 3.441},
#  {'text': "you're making incremental improvements",
#   'start': 1036.079,
#   'duration': 4.24},
#  {'text': 'and because those games are often rooted',
#   'start': 1038.24,
#   'duration': 3.679},
#  {'text': 'in something that humans did for a long',
#   'start': 1040.319,
#   'duration': 2.961},
#  {'text': 'time beforehand', 'start': 1041.919, 'duration': 3.76},
#  {'text': "there's already a strong", 'start': 1043.28, 'duration': 4.0},
#  {'text': "set of rules like it's already a damn",
#   'start': 1045.679,
#   'duration': 3.681},
#  {'text': "good benchmark yes it's really good for",
#   'start': 1047.28,
#   'duration': 3.92},
#  {'text': "so many reasons because you've got",
#   'start': 1049.36,
#   'duration': 3.52},
#  {'text': "you've got you've got clear measures of",
#   'start': 1051.2,
#   'duration': 4.24},
#  {'text': 'how good humans can be at these things',
#   'start': 1052.88,
#   'duration': 4.159},
#  {'text': "and in some cases like go we've been",
#   'start': 1055.44,
#   'duration': 4.479},
#  {'text': 'playing it for thousands of years um and',
#   'start': 1057.039,
#   'duration': 4.961},
#  {'text': 'and uh often they have scores or at',
#   'start': 1059.919,
#   'duration': 4.401},
#  {'text': "least win conditions so it's very easy",
#   'start': 1062.0,
#   'duration': 3.919},
#  {'text': 'for reward learning systems to get a',
#   'start': 1064.32,
#   'duration': 3.12},
#  {'text': "reward it's very easy to specify what",
#   'start': 1065.919,
#   'duration': 4.64},
#  {'text': 'that reward is um and uh also at the end',
#   'start': 1067.44,
#   'duration': 5.359},
#  {'text': "it's easy to you know to test uh",
#   'start': 1070.559,
#   'duration': 3.921},
#  {'text': 'externally you know', 'start': 1072.799, 'duration': 4.0},
#  {'text': 'how strong is your system by of course',
#   'start': 1074.48,
#   'duration': 3.84},
#  {'text': "playing against you know the world's",
#   'start': 1076.799,
#   'duration': 4.24},
#  {'text': "strongest players at those games so it's",
#   'start': 1078.32,
#   'duration': 4.32},
#  {'text': "it's so good for so many reasons and",
#   'start': 1081.039,
#   'duration': 3.441},
#  {'text': "it's also very efficient to run",
#   'start': 1082.64,
#   'duration': 4.08},
#  {'text': 'potentially millions of simulations in',
#   'start': 1084.48,
#   'duration': 5.12},
#  {'text': 'parallel on the cloud so um i think',
#   'start': 1086.72,
#   'duration': 4.88},
#  {'text': "there's a huge reason why we were so",
#   'start': 1089.6,
#   'duration': 4.24},
#  {'text': 'successful back in you know starting out',
#   'start': 1091.6,
#   'duration': 4.319},
#  {'text': '2010 how come we were able to progress',
#   'start': 1093.84,
#   'duration': 4.959},
#  {'text': "so quickly because we'd utilize games",
#   'start': 1095.919,
#   'duration': 5.041},
#  {'text': 'and um you know at the beginning of deep',
#   'start': 1098.799,
#   'duration': 4.481},
#  {'text': 'mind we also hired some amazing game',
#   'start': 1100.96,
#   'duration': 4.88},
#  {'text': 'engineers uh who i knew from my previous',
#   'start': 1103.28,
#   'duration': 5.44},
#  {'text': 'uh lives in the games industry and uh',
#   'start': 1105.84,
#   'duration': 4.4},
#  {'text': 'and that helped to bootstrap us very',
#   'start': 1108.72,
#   'duration': 4.0},
#  {'text': "quickly and plus it's somehow super",
#   'start': 1110.24,
#   'duration': 4.72},
#  {'text': 'compelling almost at a philosophical',
#   'start': 1112.72,
#   'duration': 5.52},
#  {'text': 'level of man versus machine', 'start': 1114.96, 'duration': 6.079},
#  {'text': 'over over a chessboard or a go board',
#   'start': 1118.24,
#   'duration': 4.559},
#  {'text': 'and especially given that the entire',
#   'start': 1121.039,
#   'duration': 3.441},
#  {'text': 'history of ai is defined by people',
#   'start': 1122.799,
#   'duration': 3.76},
#  {'text': "saying it's going to be impossible to",
#   'start': 1124.48,
#   'duration': 4.0},
#  {'text': 'make a machine that', 'start': 1126.559, 'duration': 4.321},
#  {'text': 'beats a human being in chess', 'start': 1128.48, 'duration': 4.559},
#  {'text': 'and then once that happened', 'start': 1130.88, 'duration': 4.4},
#  {'text': 'people were certain when i was coming up',
#   'start': 1133.039,
#   'duration': 4.161},
#  {'text': 'in ai that go', 'start': 1135.28, 'duration': 3.36},
#  {'text': 'is not a game that could be solved',
#   'start': 1137.2,
#   'duration': 3.92},
#  {'text': 'because of the combinatorial complexity',
#   'start': 1138.64,
#   'duration': 5.52},
#  {'text': "it's just too it's it's it's you know",
#   'start': 1141.12,
#   'duration': 5.439},
#  {'text': "no matter how much moore's law you have",
#   'start': 1144.16,
#   'duration': 4.32},
#  {'text': 'compute is just never going to be able',
#   'start': 1146.559,
#   'duration': 4.721},
# ...
#   'duration': 3.76},
#  {'text': 'enough to you know you might be able to',
#   'start': 1736.64,
#   'duration': 2.8},
#  {'text': 'do that like overnight', 'start': 1737.919, 'duration': 4.721},
#  {'text': 'do you think a game that is optimal',
#   'start': 1739.44,
#   'duration': 5.44},
#  {'text': 'designed by an ai system', 'start': 1742.64, 'duration': 5.039},
#  {'text': 'would look very much like uh planet',
#   'start': 1744.88,
#   'duration': 4.72},
#  {'text': 'earth', 'start': 1747.679, 'duration': 3.921},
#  {'text': "maybe maybe it's only the sort of game i",
#   'start': 1749.6,
#   'duration': 4.319},
#  {'text': "would love to make is is and i've tried",
#   'start': 1751.6,
#   'duration': 4.4},
#  {'text': "you know my in my game's career the",
#   'start': 1753.919,
#   'duration': 4.081},
#  {'text': 'games design career you know my first',
#   'start': 1756.0,
#   'duration': 4.24},
#  {'text': 'big game was designing a theme park an',
#   'start': 1758.0,
#   'duration': 5.039},
#  {'text': 'amusement park then uh with games like',
#   'start': 1760.24,
#   'duration': 4.799},
#  {'text': 'republic i tried to you know have games',
#   'start': 1763.039,
#   'duration': 4.081},
#  {'text': 'where we designed whole cities and and',
#   'start': 1765.039,
#   'duration': 4.321},
#  {'text': 'allowed you to play in so and of course',
#   'start': 1767.12,
#   'duration': 3.76},
#  {'text': 'people like will wright have written',
#   'start': 1769.36,
#   'duration': 3.52},
#  {'text': 'games like sim earth uh trying to',
#   'start': 1770.88,
#   'duration': 3.519},
#  {'text': 'simulate the whole of earth pretty',
#   'start': 1772.88,
#   'duration': 3.84},
#  {'text': "tricky but um i see earth i haven't",
#   'start': 1774.399,
#   'duration': 3.921},
#  {'text': 'actually played that one so what is it',
#   'start': 1776.72,
#   'duration': 3.76},
#  {'text': 'does it incorporative evolution or yeah',
#   'start': 1778.32,
#   'duration': 4.4},
#  {'text': "it has evolution and it's sort of um it",
#   'start': 1780.48,
#   'duration': 3.84},
#  {'text': 'tries to it sort of treats it as an',
#   'start': 1782.72,
#   'duration': 3.28},
#  {'text': 'entire biosphere but from quite a high',
#   'start': 1784.32,
#   'duration': 2.88},
#  {'text': 'level', 'start': 1786.0, 'duration': 2.159},
#  {'text': 'so', 'start': 1787.2, 'duration': 3.199},
#  {'text': 'nice to be able to sort of zoom in zoom',
#   'start': 1788.159,
#   'duration': 4.081},
#  {'text': 'out zoom in exactly so obviously he',
#   'start': 1790.399,
#   'duration': 3.041},
#  {'text': "couldn't do that was in the night i",
#   'start': 1792.24,
#   'duration': 2.799},
#  {'text': 'think he wrote that in the 90s so it',
#   'start': 1793.44,
#   'duration': 2.959},
#  {'text': "couldn't you know it wasn't it wasn't",
#   'start': 1795.039,
#   'duration': 3.36},
#  {'text': 'able to do that but that that would be',
#   'start': 1796.399,
#   'duration': 4.081},
#  {'text': 'uh obviously the ultimate sandbox game',
#   'start': 1798.399,
#   'duration': 2.961},
#  {'text': 'of course', 'start': 1800.48, 'duration': 2.4},
#  {'text': "on that topic do you think we're living",
#   'start': 1801.36,
#   'duration': 3.36},
#  {'text': 'in a simulation', 'start': 1802.88, 'duration': 4.08},
#  {'text': "yes well so okay so i'm gonna jump",
#   'start': 1804.72,
#   'duration': 4.48},
#  {'text': 'around from the absurdly philosophical',
#   'start': 1806.96,
#   'duration': 4.64},
#  {'text': 'to the short term sure very very happy',
#   'start': 1809.2,
#   'duration': 4.24},
#  {'text': 'to so i think uh my answer to that',
#   'start': 1811.6,
#   'duration': 4.16},
#  {'text': 'question is a little bit complex because',
#   'start': 1813.44,
#   'duration': 4.32},
#  {'text': 'uh there is simulation theory which',
#   'start': 1815.76,
#   'duration': 3.68},
#  {'text': 'obviously nick bostrom i think famously',
#   'start': 1817.76,
#   'duration': 3.84},
#  {'text': 'first proposed um', 'start': 1819.44, 'duration': 4.64},
#  {'text': "and uh i don't quite believe it in in",
#   'start': 1821.6,
#   'duration': 5.28},
#  {'text': 'that sense so um in the in the sense',
#   'start': 1824.08,
#   'duration': 4.8},
#  {'text': 'that uh are we in some sort of computer',
#   'start': 1826.88,
#   'duration': 4.799},
#  {'text': 'game or have our descendants somehow',
#   'start': 1828.88,
#   'duration': 5.6},
#  {'text': 'recreated uh uh earth in the you know',
#   'start': 1831.679,
#   'duration': 5.281},
#  {'text': '21st century and and some for some kind',
#   'start': 1834.48,
#   'duration': 5.28},
#  {'text': 'of experimental reason i think that um',
#   'start': 1836.96,
#   'duration': 5.68},
#  {'text': 'but i do think that we that that we',
#   'start': 1839.76,
#   'duration': 4.799},
#  {'text': 'might be that the best way to understand',
#   'start': 1842.64,
#   'duration': 4.88},
#  {'text': 'physics and the universe is from a',
#   'start': 1844.559,
#   'duration': 5.041},
#  {'text': 'computational perspective so', 'start': 1847.52, 'duration': 3.84},
#  {'text': 'understanding it as an information',
#   'start': 1849.6,
#   'duration': 4.4},
#  {'text': 'universe and actually information being',
#   'start': 1851.36,
#   'duration': 6.88},
#  {'text': 'the most fundamental unit of uh reality',
#   'start': 1854.0,
#   'duration': 6.0},
#  {'text': 'rather than matter or energy so a',
#   'start': 1858.24,
#   'duration': 3.6},
#  {'text': 'physicist would say you know matter or',
#   'start': 1860.0,
#   'duration': 3.6},
#  {'text': 'energy you know e equals m c squared',
#   'start': 1861.84,
#   'duration': 3.76},
#  {'text': 'these are the things that are are the',
#   'start': 1863.6,
#   'duration': 3.919},
#  {'text': "fundamentals of the universe i'd",
#   'start': 1865.6,
#   'duration': 4.4},
#  {'text': 'actually say information um which of',
#   'start': 1867.519,
#   'duration': 5.201},
#  {'text': 'course itself can be can specify energy',
#   'start': 1870.0,
#   'duration': 4.559},
#  {'text': 'or matter right matter is actually just',
#   'start': 1872.72,
#   'duration': 3.52},
#  {'text': "you know we're we're just out the way",
#   'start': 1874.559,
#   'duration': 3.441},
#  {'text': 'our bodies and all the molecules in our',
#   'start': 1876.24,
#   'duration': 4.08},
#  {'text': 'body arrange is information so i think',
#   'start': 1878.0,
#   'duration': 4.799},
#  {'text': 'information may be the most fundamental',
#   'start': 1880.32,
#   'duration': 4.64},
#  {'text': 'way to describe the universe and',
#   'start': 1882.799,
#   'duration': 4.401},
#  {'text': "therefore you could say we're in some",
#   'start': 1884.96,
#   'duration': 4.719},
#  {'text': 'sort of simulation because of that um',
#   'start': 1887.2,
#   'duration': 4.16},
#  {'text': "but i don't i do i'm not i'm not really",
#   'start': 1889.679,
#   'duration': 4.24},
#  {'text': 'a subscriber to the idea that um you',
#   'start': 1891.36,
#   'duration': 4.08},
#  {'text': 'know these are sort of throw away',
#   'start': 1893.919,
#   'duration': 3.12},
#  {'text': 'billions of simulations around i think',
#   'start': 1895.44,
#   'duration': 4.16},
#  {'text': 'this is actually very critical and',
#   'start': 1897.039,
#   'duration': 4.88},
#  {'text': 'possibly unique this simulation',
#   'start': 1899.6,
#   'duration': 4.319},
#  {'text': 'particular one yes so but and you just',
#   'start': 1901.919,
#   'duration': 3.281},
#  {'text': 'mean', 'start': 1903.919, 'duration': 3.041},
#  {'text': 'treating the universe', 'start': 1905.2, 'duration': 3.52},
#  {'text': 'as a computer', 'start': 1906.96, 'duration': 2.719},
#  {'text': "that's", 'start': 1908.72, 'duration': 3.439},
#  {'text': 'processing and modifying information',
#   'start': 1909.679,
#   'duration': 4.161},
#  {'text': 'is is a good way to solve the problems',
#   'start': 1912.159,
#   'duration': 5.041},
#  {'text': 'of physics of chemistry of biology',
#   'start': 1913.84,
#   'duration': 6.24},
#  {'text': 'and perhaps of humanity and so on yes i',
#   'start': 1917.2,
#   'duration': 5.68},
#  {'text': 'think understanding physics in terms of',
#   'start': 1920.08,
#   'duration': 5.52},
#  {'text': 'information theory uh might be the best',
#   'start': 1922.88,
#   'duration': 5.12},
#  {'text': "way to to really uh understand what's",
#   'start': 1925.6,
#   'duration': 3.679},
#  {'text': 'going on here', 'start': 1928.0, 'duration': 4.32},
#  {'text': 'from our understanding of a universal',
#   'start': 1929.279,
#   'duration': 5.361},
#  {'text': 'turing machine from our understanding of',
#   'start': 1932.32,
#   'duration': 3.44},
#  {'text': "a computer do you think there's",
#   'start': 1934.64,
#   'duration': 3.68},
#  {'text': 'something outside of the capabilities of',
#   'start': 1935.76,
#   'duration': 4.639},
#  {'text': 'a computer that is present in our',
#   'start': 1938.32,
#   'duration': 4.239},
#  {'text': 'universe you have a disagreement with',
#   'start': 1940.399,
#   'duration': 3.681},
#  {'text': 'roger penrose', 'start': 1942.559, 'duration': 3.761},
#  {'text': 'the nature of consciousness he he thinks',
#   'start': 1944.08,
#   'duration': 3.92},
#  {'text': 'that consciousness is more than just a',
#   'start': 1946.32,
#   'duration': 3.28},
#  {'text': 'computation', 'start': 1948.0, 'duration': 3.6},
#  {'text': 'uh do you think all of it the whole',
#   'start': 1949.6,
#   'duration': 4.319},
#  {'text': 'shebang is can be can be a competition',
#   'start': 1951.6,
#   'duration': 4.079},
#  {'text': "yeah i've had many fascinating debates",
#   'start': 1953.919,
#   'duration': 4.161},
#  {'text': 'with uh sir roger penrose and obviously',
#   'start': 1955.679,
#   'duration': 4.641},
#  {'text': "he's he's famously and i read you know",
#   'start': 1958.08,
#   'duration': 4.64},
#  {'text': 'emperors of new mind and and um',
#   'start': 1960.32,
#   'duration': 4.8},
#  {'text': 'and his books uh his classical books uh',
#   'start': 1962.72,
#   'duration': 3.839},
#  {'text': 'and they they were pretty influential',
#   'start': 1965.12,
#   'duration': 3.76},
#  {'text': 'and you know in the 90s and um he',
#   'start': 1966.559,
#   'duration': 4.0},
#  {'text': "believes that there's something more you",
#   'start': 1968.88,
#   'duration': 4.159},
#  {'text': 'know something quantum that is needed to',
#   'start': 1970.559,
#   'duration': 5.36},
#  {'text': 'explain consciousness in the brain um i',
#   'start': 1973.039,
#   'duration': 4.64},
#  {'text': "think about what we're doing actually at",
#   'start': 1975.919,
#   'duration': 3.76},
#  {'text': 'deepmind and what my career is being',
#   'start': 1977.679,
#   'duration': 4.24},
#  {'text': "we're almost like true rings champion so",
#   'start': 1979.679,
#   'duration': 3.921},
#  {'text': 'we are pushing turing machines or',
#   'start': 1981.919,
#   'duration': 4.161},
#  {'text': 'classical computation to the limits what',
#   'start': 1983.6,
#   'duration': 4.4},
#  {'text': 'are the limits of what classical',
#   'start': 1986.08,
#   'duration': 4.959},
#  {'text': 'computing can do now um and at the same',
#   'start': 1988.0,
#   'duration': 5.679},
#  {'text': "time i've also studied neuroscience to",
#   'start': 1991.039,
#   'duration': 4.48},
#  {'text': "see and that's why i did my phd in was",
#   'start': 1993.679,
#   'duration': 4.161},
#  {'text': 'to see also to look at you know is there',
#   'start': 1995.519,
#   'duration': 3.76},
#  {'text': 'anything quantum in the brain from a',
#   'start': 1997.84,
#   'duration': 3.28},
#  {'text': 'neuroscience or biological perspective',
#   'start': 1999.279,
#   'duration': 4.321},
#  {'text': 'and um and so far i think most',
#   'start': 2001.12,
#   'duration': 3.919},
#  {'text': 'neuroscientists and most mainstream',
#   'start': 2003.6,
#   'duration': 2.959},
#  {'text': 'biologists and neuroscientists would say',
#   'start': 2005.039,
#   'duration': 3.76},
#  {'text': "there's no evidence of any quantum uh",
#   'start': 2006.559,
#   'duration': 4.321},
#  {'text': 'systems or effects in the brain as far',
#   'start': 2008.799,
#   'duration': 3.681},
#  {'text': "as we can see it's it can be mostly",
#   'start': 2010.88,
#   'duration': 4.08},
#  {'text': 'explained by classical uh classical',
#   'start': 2012.48,
#   'duration': 4.559},
#  {'text': 'theories so', 'start': 2014.96, 'duration': 3.92},
#  {'text': "and then so there's sort of the the",
#   'start': 2017.039,
#   'duration': 4.081},
#  {'text': 'search from the biology side and then at',
#   'start': 2018.88,
#   'duration': 4.32},
#  {'text': "the same time there's the raising of the",
#   'start': 2021.12,
#   'duration': 4.799},
#  {'text': 'water uh at the bar from what classical',
#   'start': 2023.2,
#   'duration': 5.68},
#  {'text': 'turing machines can do uh uh and',
#   'start': 2025.919,
#   'duration': 4.801},
#  {'text': 'and you know including our new ai',
#   'start': 2028.88,
#   'duration': 5.12},
#  {'text': 'systems and uh as you alluded to earlier',
#   'start': 2030.72,
#   'duration': 5.679},
#  {'text': 'um you know i think ai especially in the',
#   'start': 2034.0,
#   'duration': 5.12},
#  {'text': 'last decade plus has been a continual',
#   'start': 2036.399,
#   'duration': 5.921},
#  {'text': 'story now of surprising uh events uh and',
#   'start': 2039.12,
#   'duration': 5.6},
#  {'text': 'surprising successes knocking over one',
#   'start': 2042.32,
#   'duration': 4.079},
#  {'text': 'theory after another of what was thought',
#   'start': 2044.72,
#   'duration': 3.76},
#  {'text': 'to be impossible you know from go to',
#   'start': 2046.399,
#   'duration': 5.121},
#  {'text': 'protein folding and so on and so i think',
#   'start': 2048.48,
#   'duration': 4.0},
#  {'text': 'um', 'start': 2051.52, 'duration': 4.559},
#  {'text': 'i would be very hesitant to bet against',
#   'start': 2052.48,
#   'duration': 6.96},
#  {'text': 'how far the uh universal turing machine',
#   'start': 2056.079,
#   'duration': 6.56},
#  {'text': 'and classical computation paradigm can',
#   'start': 2059.44,
#   'duration': 5.84},
#  {'text': 'go and and my betting would be',
#   'start': 2062.639,
#   'duration': 5.121},
#  {'text': "that all of certainly what's going on in",
#   'start': 2065.28,
#   'duration': 5.599},
#  {'text': 'our brain uh can probably be mimicked or',
#   'start': 2067.76,
#   'duration': 5.599},
#  {'text': 'or approximated on a on a classical',
#   'start': 2070.879,
#   'duration': 5.04},
#  {'text': 'machine um not you know not requiring',
#   'start': 2073.359,
#   'duration': 5.121},
#  {'text': 'something metaphysical or quantum and',
#   'start': 2075.919,
#   'duration': 4.321},
#  {'text': "we'll get there with some of the work",
#   'start': 2078.48,
#   'duration': 3.199},
#  {'text': 'with alpha fold', 'start': 2080.24, 'duration': 4.159},
#  {'text': 'which i think begins the journey of',
#   'start': 2081.679,
#   'duration': 4.72},
#  {'text': 'modeling this beautiful and complex',
#   'start': 2084.399,
#   'duration': 4.401},
#  {'text': 'world of biology so you think all the',
#   'start': 2086.399,
#   'duration': 4.881},
#  {'text': 'magic of the human mind comes from this',
#   'start': 2088.8,
#   'duration': 5.359},
#  {'text': 'just a few pounds of mush', 'start': 2091.28, 'duration': 6.079},
#  {'text': 'of a biological computational mush',
#   'start': 2094.159,
#   'duration': 4.081},
#  {'text': "that's", 'start': 2097.359, 'duration': 4.081},
#  {'text': 'akin to some of the neural networks',
#   'start': 2098.24,
#   'duration': 6.24},
#  {'text': 'not directly but in spirit that deep',
#   'start': 2101.44,
#   'duration': 5.12},
#  {'text': 'mind has been working with well look i',
#   'start': 2104.48,
#   'duration': 3.84},
#  {'text': "think it's um you say it's a few you",
#   'start': 2106.56,
#   'duration': 3.36},
#  {'text': "know of course it's this is the i think",
#   'start': 2108.32,
#   'duration': 3.279},
#  {'text': 'the biggest miracle of the universe is',
#   'start': 2109.92,
#   'duration': 4.159},
#  {'text': 'that um it is just a few pounds of mush',
#   'start': 2111.599,
#   'duration': 4.641},
#  {'text': "in our skulls and yet it's also our",
#   'start': 2114.079,
#   'duration': 4.0},
#  {'text': 'brains are the most complex objects in',
#   'start': 2116.24,
#   'duration': 3.92},
#  {'text': 'the in that we know of in the universe',
#   'start': 2118.079,
#   'duration': 3.601},
#  {'text': "so there's something profoundly",
#   'start': 2120.16,
#   'duration': 3.679},
#  {'text': 'beautiful and amazing about our brains',
#   'start': 2121.68,
#   'duration': 2.96},
#  ...]

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([transcript])

# %%
len(chunks)
# Out:
# 168

# %%
chunks[100]
# Out:
# Document(metadata={}, page_content="and and kind of come up with descriptions of the electron clouds where they're gonna go how they're gonna interact when you put two elements together uh and what we try to do is learn a simulation uh uh learner functional that will describe more chemistry types of chemistry so um until now you know you can run expensive simulations but then you can only simulate very small uh molecules very simple molecules we would like to simulate large materials um and so uh today there's no way of doing that and we're building up towards uh building functionals that approximate schrodinger's equation and then allow you to describe uh what the electrons are doing and all materials sort of science and material properties are governed by the electrons and and how they interact so have a good summarization of the simulation through the functional um but one that is still close to what the actual simulation would come out with so what um how difficult is that to ask what's involved in that task is it")

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '94467a1b-f744-4939-9c57-90a9bd721e26',
#  1: 'b2809fb8-084c-4c1d-abef-c5fdbcb750ad',
#  2: '3c844e5c-ce87-45c6-8a61-cd56c78d30fe',
#  3: 'd09c2128-6c9d-414b-a1c1-1b04ce8486b2',
#  4: '4fbbdf26-eb61-4754-ad19-dc46495fad99',
#  5: '9767d74c-e2f9-4436-9bf5-943ca2f9ad3d',
#  6: '8309b7f4-fade-4c6a-9ac4-47462b0cce8b',
#  7: '5deb994b-8f56-46dc-a438-74d736c27542',
#  8: '0a505928-84d5-4e08-8cb8-aff18beb83ec',
#  9: '3774db94-55f7-40fc-b4dc-ae34f11c11a2',
#  10: '62365edd-708d-4fe5-8304-f88e16428d8f',
#  11: 'd7a8b29f-6df2-45e6-afde-dbed18a033d7',
#  12: '6cdea144-5b59-4eee-9d36-f9d0c8ec8d7c',
#  13: 'b1694a2e-6f9f-4f15-872a-344ee410c16d',
#  14: 'fae08a51-703c-40c7-ad75-9ea13db38b27',
#  15: '257cd33a-ba0a-407b-aba6-824d73880b87',
#  16: 'a284f81f-7989-4841-93f2-c0175ed61f25',
#  17: '33774982-b64e-4bf6-9e4b-c624cba2ae06',
#  18: '2a93c57f-d44e-4740-9e9b-a94eae9b0c0c',
#  19: '86778b0a-8e80-4591-ba79-ac18db581ecd',
#  20: 'd9a3d294-e8dc-41b4-8948-95b4abbc2bb1',
#  21: '85a2ec42-31fe-4502-9257-1bc5edf7535f',
#  22: '5eb0015c-8e0b-435e-b0db-56bad845a4c2',
#  23: '2f92096f-f910-42b3-83f1-fedf568211a6',
#  24: '28dabbed-1afc-4c60-9df2-3ff61bbeba12',
#  25: 'dabd31af-95f2-4145-bd4b-853b65eb0b3e',
#  26: '0c98d824-7297-4caa-be60-d0cfb09f683f',
#  27: '0ff9da8c-18e5-4256-ae58-af8391303c61',
#  28: 'a4c36a09-3267-4fa0-8d75-1378048be025',
#  29: '29e22937-711b-44dd-86c9-205b71736a4d',
#  30: 'ac5f92ba-ec7f-4d39-bcf4-c28d82ae99cf',
#  31: 'ac64a54f-1765-4a6d-9d1f-9b62323ec364',
#  32: 'c5deda90-85e3-40ee-8693-8829ac9bdbaf',
#  33: '4f62ae2c-fd1f-44c4-b308-df2cac4f05e6',
#  34: 'e29d534f-5f3c-4483-90a9-ffce8281f72a',
#  35: '61cb02a2-54cf-4f96-a824-e2a7c071a3c8',
#  36: '44f24449-5e08-4220-b2be-16737aad0559',
#  37: '27b25603-e7a8-4db5-b395-09f9bca0e44b',
#  38: '0ae401f4-3714-4a57-9081-ad40dc9cb231',
#  39: '0f151566-f01f-4877-8a7c-7e6b23d667f8',
#  40: '24cc0f83-8eb2-4ee8-aec0-caf7ff8ee222',
#  41: 'e7291c7b-daf7-41ca-ab61-f41082607094',
#  42: 'b726c886-c477-400f-a8ad-998f83307f60',
#  43: '4667c12e-8774-47a9-a658-09daaa4553fd',
#  44: '036908a5-5dcf-4c16-b4ec-9eaee79971a7',
#  45: 'bd2a51eb-f75a-49c9-b912-a212ff8070e4',
#  46: '7f4ced4a-9fef-4431-be14-faae14c41ee3',
#  47: '84e17136-b86f-41cd-a3d0-a0b69702a0b6',
#  48: 'e31d3140-64e1-4303-8449-1d8e8f2c01ab',
#  49: '2f2c6ff0-e2f2-4673-9159-ea675b4439b5',
#  50: 'eb9cb13a-7b5c-4ade-98a7-c24cfbb01451',
#  51: 'e33ed1ef-5698-4132-a392-9a1c247e9810',
#  52: '2fb08fc7-9d3c-4cd3-89e3-fbd08d811a0e',
#  53: 'a39ae805-c478-43b3-9842-2e7987ea304f',
#  54: 'e31d61b2-decd-497b-8af1-662842fa6526',
#  55: 'cef50208-10d0-4919-a666-6d70bbac604f',
#  56: 'e7d1271a-da2e-4d17-86ac-e6339326ebc2',
#  57: '743a8e0f-aca0-4575-8425-e7424a25a174',
#  58: '800af802-6a45-42d8-aafa-e31948a52245',
#  59: '4a06d22c-3372-4986-b7de-b7987fda1c8c',
#  60: '5aec2ee8-cf70-429f-94a1-809fe3b6c439',
#  61: 'c630d102-4912-4304-b2f5-c56fe8cf8b17',
#  62: '1bdde98b-b9e7-48ac-809e-ffceb452f288',
#  63: '79c0e6b8-4de8-4a4e-bc69-f2e3d32674df',
#  64: '2bfeb085-7f2c-40b9-bf2f-c70dcbe605cd',
#  65: '0e11935b-e941-4a2f-829d-8928a155839e',
#  66: '5a9a7091-3213-4021-a206-ecf54feb2b9c',
#  67: 'da424647-0471-4226-8a5a-8ea4365a8ec2',
#  68: '51692219-9f54-4bc0-99ca-f40987c25f95',
#  69: '7a5d8008-2668-48b9-9111-d58a0914e596',
#  70: 'fe9e3810-e0dc-4d6d-a08e-1fe0e5fa0041',
#  71: 'b9ffa2ab-3c48-49cc-a3b4-e495b44ef67a',
#  72: '8184389f-4447-496e-9af8-0c2be80772d4',
#  73: '55ab3770-d96c-4e09-af80-a8360896233a',
#  74: '066590b2-2a43-4c74-8d39-44a25f1d5bcf',
#  75: 'bbf73316-24d8-44ca-ae3d-97d3c618d091',
#  76: '1a64f924-346e-4a62-9358-7e99e36512fe',
#  77: '965600c4-37af-41d0-b255-d9e23507017d',
#  78: '6b21120a-8d43-4df4-8acd-1fefd5dcb5d3',
#  79: '901fb737-8613-4937-80ff-be72544cc958',
#  80: '2984c36f-52fb-4ebd-a366-af5657966dc1',
#  81: '25f70cdc-44aa-46c2-80fa-1fa7d596714a',
#  82: 'f26a2a57-348c-4cea-9280-3847d60fc967',
#  83: '69a78a7b-70f3-4242-82d9-ef666441b047',
#  84: '0ab57d7d-f0e1-43ae-900d-84a62eabdf37',
#  85: '382d390e-53df-44aa-a170-9339520603ef',
#  86: '02d69ecd-7198-40c8-bfb7-823156b2ef74',
#  87: 'de9cdb8f-60c8-4912-b8a3-085cc641690f',
#  88: '5725ccf8-2ade-4418-844b-797db1ffd53d',
#  89: 'ae0fab6a-059a-466e-b503-63551ac39cc2',
#  90: '37c3be66-4171-41ab-8e35-6f8763cfbd23',
#  91: '0b3d3947-e834-48d9-93ef-ad29c286e5a9',
#  92: '62919e68-64f5-416a-8f3d-6e8e650bdb64',
#  93: '668f499c-074e-4075-bbb0-bb374371daf5',
#  94: '5a7a9106-634e-428f-957f-cc40b77e26cf',
#  95: '9945ea1d-f77a-4b07-b32d-998ece2840a6',
#  96: '7967d013-c538-4b56-a16d-0da0998fbdd1',
#  97: 'f9ea4672-1fc2-4667-86fb-877ca7f1018c',
#  98: '29f576c2-d6ab-48bb-b99a-c4bac2763e44',
#  99: '75cad4b5-bd29-42fd-bce1-8aa1717466b8',
#  100: '951e27e2-c6a0-47ea-95aa-f784b87bd846',
#  101: '93fc91b7-e915-4f03-9454-d654477f2a8c',
#  102: '46281529-d330-460b-9e95-a251d9bddcff',
#  103: 'fd359cc7-b4e7-4bd5-af1d-2377107978a5',
#  104: '9085651c-6f09-49b9-b5a4-5a6dd298ab0c',
#  105: 'cedb8812-e1a8-48e5-9fc1-6721e9518bba',
#  106: 'd77a23f5-402e-43df-9ec4-7ebc26d4ac52',
#  107: '808bbcf3-2bca-4abf-a57f-f1043da6b29f',
#  108: 'f003b6c9-aa1a-4dbd-8d0e-57f77da17d65',
#  109: '5b0aaca0-fd4c-4e25-a290-a5840bfaacbc',
#  110: '3e8381ee-ff33-4f7e-975a-690b9d96b503',
#  111: 'c411779e-f4af-4774-a118-e7ef64f4938c',
#  112: '0c2c4b59-716d-466b-b1d0-52171fd85318',
#  113: 'a67234db-a466-4826-aaff-2d0dba20d9e1',
#  114: '81fe0279-130c-4ff5-9261-63230953e66d',
#  115: '8252df61-ed1d-4133-8620-48ad1d942553',
#  116: '814f784b-80aa-46e8-b549-7ae3984ae789',
#  117: '94d78b99-aaaf-4760-a0ff-83dcdadd12ef',
#  118: '63d4280f-247b-4b14-b120-126560c79633',
#  119: '41867f4c-34f3-405b-81c4-25ecf987720d',
#  120: '90bf1d93-ecf6-4c7c-824a-6a7039bc5aff',
#  121: '8baaead9-89ff-4886-9480-571c3cbb619a',
#  122: 'e0b1f27b-04d3-4521-a2d7-f3b438d8d3e3',
#  123: '66753439-c215-457a-8df4-e81db2aa43d9',
#  124: 'b0e0ce8d-a443-4b03-be34-db9e4a0c6d75',
#  125: '4982329b-8461-42df-96a6-4930d1eaaa1f',
#  126: 'c48d86d6-efd8-4074-987c-3bd0e9b9b642',
#  127: 'e256bf1a-5d6d-4b20-b118-b406f75cb52d',
#  128: 'a184bdaa-a085-4d40-870d-4c3ee0f4dd1c',
#  129: '5dba1a49-64e1-43d0-a393-da30624639df',
#  130: '6aad2b5e-4da0-464a-9a04-243dabc34b69',
#  131: 'b1680c19-487a-4d24-88c9-81f37b3f5426',
#  132: '1e49c4ae-9c01-4be8-9f96-09d5a7cc3ebd',
#  133: '23e2d119-8d7e-4ed2-ac58-fc3442a7ee32',
#  134: 'e9dd9194-dfe7-4d72-a8ee-bd694caed4d8',
#  135: '53fc4aad-10de-466d-8066-b20fa2a784bd',
#  136: '195cc05e-6ab6-4efd-a853-43ef757f4990',
#  137: 'b4c13413-17ff-4694-9660-c724b64854c0',
#  138: '31ad9445-fdbe-4030-83cd-3d16fe90aeae',
#  139: '6eb6a76c-ac30-4773-8d72-2ccb102c20fd',
#  140: 'c884181e-9603-41a6-b93b-a8ce7bb31a75',
#  141: 'c8a02eae-0703-4e86-9a95-83034eca4df0',
#  142: 'b11cff99-ae74-42d3-94f9-575cd1296037',
#  143: '88317d10-21d5-4646-a08d-0975d071e109',
#  144: 'e1616fe8-0a8a-42b8-9b6a-ed4ff206dd37',
#  145: '5255bec4-4a98-4670-a9ae-b3794d1ac631',
#  146: '0361bf18-00d5-497a-b161-bed6f8e94aad',
#  147: '6f77f6db-e9a8-4854-be0c-08e39712d0a9',
#  148: 'b7200dc8-3a5b-41ba-8cc7-a5f3414251a9',
#  149: 'cdd6c3cc-a7bf-4c96-bfbf-18eb28ed652f',
#  150: 'a425eff5-49eb-43b4-8972-66a85b340370',
#  151: '619de910-59a4-4a27-b612-186e84201a64',
#  152: 'b3a4a24c-8129-4457-871e-ea4b360c0a90',
#  153: '50f4e6b1-203d-4db9-a0b5-97fab872d32a',
#  154: '6c34f9d0-e8f0-464d-bfc3-1ce964f00394',
#  155: '455ee6f3-d287-4728-863f-064647d22ec3',
#  156: '2b13d87b-3e9f-4a34-82ae-48658669de1b',
#  157: '4ef6c0db-6a81-488a-a34d-c5e26e7e087f',
#  158: 'de8cbbf2-52d3-4e14-87c4-7d917675a8f8',
#  159: '6fed38c6-b719-46fe-ba8e-616781071752',
#  160: '989e4a24-c44f-4b32-8c75-1bb2f49b8794',
#  161: '0be8636b-2195-4aa6-bce5-0f2a9f58b4bf',
#  162: 'bdd5b5d1-d683-41b5-8b29-a1ca40c58917',
#  163: 'f4d38fbf-60a8-4cdf-8539-4b367f21e342',
#  164: 'a6c8d3da-7f96-4693-8b4c-99da48def04d',
#  165: '6a34f39c-4a50-4e7c-a317-adfc799201ab',
#  166: 'd0048567-7a01-4962-b6a3-809406dfa6c5',
#  167: '8f9968ee-a3d5-4faa-be4b-e05fbaf1c272'}

# %%
vector_store.get_by_ids(['2436bdb8-3f5f-49c6-8915-0c654c888700'])
# Out:
# []

# %% [markdown]
# # **Retrieval**

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7ece1a9fad90>, search_kwargs={'k': 4})

# %%
retriever.invoke('What is deepmind')
# Out:
# [Document(id='94467a1b-f744-4939-9c57-90a9bd721e26', metadata={}, page_content="the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough"),
#  Document(id='da424647-0471-4226-8a5a-8ea4365a8ec2', metadata={}, page_content='i used to discuss um uh uh what were the sort of founding tenets of deep mind and it was very various things one was um algorithmic advances so deep learning you know jeff hinton and cohen just had just sort of invented that in academia but no one in industry knew about it uh we love reinforcement learning we thought that could be scaled up but also understanding about the human brain had advanced um quite a lot uh in the decade prior with fmri machines and other things so we could get some good hints about architectures and algorithms and and sort of um representations maybe that the brain uses so as at a systems level not at a implementation level um and then the other big things were compute and gpus right so we could see a compute was going to be really useful and it got to a place where it became commoditized mostly through the games industry and and that could be taken advantage of and then the final thing was also mathematical and theoretical definitions of intelligence so'),
#  Document(id='2bfeb085-7f2c-40b9-bf2f-c70dcbe605cd', metadata={}, page_content="and how it works this is tough to uh ask you this question because you probably will say it's everything but let's let's try let's try to think to this because you're in a very interesting position where deepmind is the place of some of the most uh brilliant ideas in the history of ai but it's also a place of brilliant engineering so how much of solving intelligence this big goal for deepmind how much of it is science how much is engineering so how much is the algorithms how much is the data how much is the hardware compute infrastructure how much is it the software computer infrastructure yeah um what else is there how much is the human infrastructure and like just the humans interact in certain kinds of ways in all the space of all those ideas how much does maybe like philosophy how much what's the key if um uh if if you were to sort of look back like if we go forward 200 years look back what was the key thing that solved intelligence is that ideas i think it's a combination first"),
#  Document(id='55ab3770-d96c-4e09-af80-a8360896233a', metadata={}, page_content="ambitious as trying to solve intelligence and you're you're you know it's blue sky research no one knows how to do it you you you need to use any evidence or any source of information you can to help guide you in the right direction or give you confidence you're going in the right direction so so that that was one reason we pushed so hard on that and that's and just going back to your early question about organization the other big thing that i think we innovated with at deepmind to encourage invention and and uh and innovation was the multi-disciplinary organization we built and we still have today so deepmind originally was a confluence of the of the most cutting-edge knowledge in neuroscience with machine learning engineering and mathematics right and and gaming and then since then we built that out even further so we have philosophers here and and uh by you know ethicists but also other types of scientists physicists and so on um and that's what brings together i tried to build a")]

# %% [markdown]
# # **Augmentation:**

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2)

# %%
prompt = PromptTemplate(
    template="""
      You are a helpful assistant.
      Answer ONLY from the provided transcript context.
      If the context is insufficient, just say you don't know.

      {context}
      Question: {question}
    """,
    input_variables = ['context', 'question']
)

# %%
question          = "is the topic of nuclear fusion discussed in this video? if yes then what was discussed"
retrieved_docs    = retriever.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='29f576c2-d6ab-48bb-b99a-c4bac2763e44', metadata={}, page_content="so we with this problem and we published it in a nature paper last year uh we held the fusion that we held the plasma in specific shapes so actually it's almost like carving the plasma into different shapes and control and hold it there for the record amount of time so um so that's one of the problems of of fusion sort of um solved so i have a controller that's able to no matter the shape uh contain it continue yeah contain it and hold it in structure and there's different shapes that are better for for the energy productions called droplets and and and so on so um so that was huge and now we're looking we're talking to lots of fusion startups to see what's the next problem we can tackle uh in the fusion area so another fascinating place in a paper title pushing the frontiers of density functionals by solving the fractional electron problem so you're taking on modeling and simulating the quantum mechanical behavior of electrons yes um can you explain this work and can ai model and"),
#  Document(id='9945ea1d-f77a-4b07-b32d-998ece2840a6', metadata={}, page_content="in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double checked with the team we were going to use carefully and safely i was impressed they managed to persuade them to let us use it and um and it's a it's an amazing test reactor they have there and they try all sorts of pretty crazy experiments on it and um the the the what we tend to look at is if we go into a new domain like fusion what are all the bottleneck problems uh like thinking from first principles you know what are all the bottleneck problems that are still stopping fusion working today and then we look at we you know we get a fusion expert to tell us and then we look at those bottlenecks and we look at the ones which ones are amenable to our ai methods today yes right and and and then and would be interesting from a research perspective from our point of view from an ai point of"),
#  Document(id='5a7a9106-634e-428f-957f-cc40b77e26cf', metadata={}, page_content='that i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so energy and climate so we talked about disease and biology as being one of the biggest places i think ai can help with i think energy and climate uh is another one so maybe they would be my top two um and fusion is one one area i think ai can help with now fusion has many challenges mostly physics material science and engineering challenges as well to build these massive fusion reactors and contain the plasma and what we try to do whenever we go into a new field to apply our systems is we look for um we talk to domain experts we try and find the best people in the world to collaborate with um in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double'),
#  Document(id='668f499c-074e-4075-bbb0-bb374371daf5', metadata={}, page_content="like room temperature superconductors or something on my list one day i'd like to like you know have an ai system to help build better optimized batteries all of these sort of mechanical things mr i think a systematic sort of search could be uh guided by a model could be um could be extremely powerful so speaking of which you have a paper on nuclear fusion uh magnetic control of tokamak plasmas to deep reinforcement learning so you uh you're seeking to solve nuclear fusion with deep rl so it's doing control of high temperature plasmas can you explain this work and uh can ai eventually solve nuclear fusion it's been very fun last year or two and very productive because we've been taking off a lot of my dream projects if you like of things that i've collected over the years of areas of science that i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so")]

# %%
context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
context_text
# Out:
# "so we with this problem and we published it in a nature paper last year uh we held the fusion that we held the plasma in specific shapes so actually it's almost like carving the plasma into different shapes and control and hold it there for the record amount of time so um so that's one of the problems of of fusion sort of um solved so i have a controller that's able to no matter the shape uh contain it continue yeah contain it and hold it in structure and there's different shapes that are better for for the energy productions called droplets and and and so on so um so that was huge and now we're looking we're talking to lots of fusion startups to see what's the next problem we can tackle uh in the fusion area so another fascinating place in a paper title pushing the frontiers of density functionals by solving the fractional electron problem so you're taking on modeling and simulating the quantum mechanical behavior of electrons yes um can you explain this work and can ai model and\n\nin this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double checked with the team we were going to use carefully and safely i was impressed they managed to persuade them to let us use it and um and it's a it's an amazing test reactor they have there and they try all sorts of pretty crazy experiments on it and um the the the what we tend to look at is if we go into a new domain like fusion what are all the bottleneck problems uh like thinking from first principles you know what are all the bottleneck problems that are still stopping fusion working today and then we look at we you know we get a fusion expert to tell us and then we look at those bottlenecks and we look at the ones which ones are amenable to our ai methods today yes right and and and then and would be interesting from a research perspective from our point of view from an ai point of\n\nthat i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so energy and climate so we talked about disease and biology as being one of the biggest places i think ai can help with i think energy and climate uh is another one so maybe they would be my top two um and fusion is one one area i think ai can help with now fusion has many challenges mostly physics material science and engineering challenges as well to build these massive fusion reactors and contain the plasma and what we try to do whenever we go into a new field to apply our systems is we look for um we talk to domain experts we try and find the best people in the world to collaborate with um in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double\n\nlike room temperature superconductors or something on my list one day i'd like to like you know have an ai system to help build better optimized batteries all of these sort of mechanical things mr i think a systematic sort of search could be uh guided by a model could be um could be extremely powerful so speaking of which you have a paper on nuclear fusion uh magnetic control of tokamak plasmas to deep reinforcement learning so you uh you're seeking to solve nuclear fusion with deep rl so it's doing control of high temperature plasmas can you explain this work and uh can ai eventually solve nuclear fusion it's been very fun last year or two and very productive because we've been taking off a lot of my dream projects if you like of things that i've collected over the years of areas of science that i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so"

# %%
final_prompt = prompt.invoke({"context": context_text, "question": question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n      You are a helpful assistant.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don't know.\n\n      so we with this problem and we published it in a nature paper last year uh we held the fusion that we held the plasma in specific shapes so actually it's almost like carving the plasma into different shapes and control and hold it there for the record amount of time so um so that's one of the problems of of fusion sort of um solved so i have a controller that's able to no matter the shape uh contain it continue yeah contain it and hold it in structure and there's different shapes that are better for for the energy productions called droplets and and and so on so um so that was huge and now we're looking we're talking to lots of fusion startups to see what's the next problem we can tackle uh in the fusion area so another fascinating place in a paper title pushing the frontiers of density functionals by solving the fractional electron problem so you're taking on modeling and simulating the quantum mechanical behavior of electrons yes um can you explain this work and can ai model and\n\nin this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double checked with the team we were going to use carefully and safely i was impressed they managed to persuade them to let us use it and um and it's a it's an amazing test reactor they have there and they try all sorts of pretty crazy experiments on it and um the the the what we tend to look at is if we go into a new domain like fusion what are all the bottleneck problems uh like thinking from first principles you know what are all the bottleneck problems that are still stopping fusion working today and then we look at we you know we get a fusion expert to tell us and then we look at those bottlenecks and we look at the ones which ones are amenable to our ai methods today yes right and and and then and would be interesting from a research perspective from our point of view from an ai point of\n\nthat i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so energy and climate so we talked about disease and biology as being one of the biggest places i think ai can help with i think energy and climate uh is another one so maybe they would be my top two um and fusion is one one area i think ai can help with now fusion has many challenges mostly physics material science and engineering challenges as well to build these massive fusion reactors and contain the plasma and what we try to do whenever we go into a new field to apply our systems is we look for um we talk to domain experts we try and find the best people in the world to collaborate with um in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double\n\nlike room temperature superconductors or something on my list one day i'd like to like you know have an ai system to help build better optimized batteries all of these sort of mechanical things mr i think a systematic sort of search could be uh guided by a model could be um could be extremely powerful so speaking of which you have a paper on nuclear fusion uh magnetic control of tokamak plasmas to deep reinforcement learning so you uh you're seeking to solve nuclear fusion with deep rl so it's doing control of high temperature plasmas can you explain this work and uh can ai eventually solve nuclear fusion it's been very fun last year or two and very productive because we've been taking off a lot of my dream projects if you like of things that i've collected over the years of areas of science that i wou ...

# %% [markdown]
# ## **Generation**

# %%
answer = llm.invoke(final_prompt)
print(answer.content)
# Out:
# Yes, the topic of nuclear fusion is discussed in the video. The discussion includes the following points:
#
# 1. The speaker mentions a problem in fusion that was published in a Nature paper, where they held plasma in specific shapes to control and contain it for a record amount of time. They describe this process as "carving the plasma into different shapes."
#
# 2. They talk about collaborating with EPFL in Switzerland, which has a test reactor that they used for their experiments. The speaker emphasizes the importance of identifying bottleneck problems in fusion and how their AI methods can address these challenges.
#
# 3. The speaker expresses the belief that AI can help accelerate solutions in energy and climate, particularly in the field of fusion, which faces various challenges in physics, material science, and engineering.
#
# 4. They mention a specific paper on "magnetic control of tokamak plasmas using deep reinforcement learning," indicating their work on controlling high-temperature plasmas and exploring the potential of AI to solve nuclear fusion challenges.

# %% [markdown]
# # **building chain**

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('who is Demis')
# Out:
# {'context': "the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough\n\ndeeper maybe simpler explanation yes of things right than the standard model of physics which we know doesn't work but we still keep adding to so um and and that's how i think the beginning of an explanation would look and it would start encompassing many of the mysteries that we have wondered about for thousands of years like you know consciousness uh life and gravity all of these things yeah giving us a glimpses of explanations for those things yeah well um damas dear one of the special human beings in this giant puzzle of ours and it's a huge honor that you would take a pause from the bigger puzzle to solve this small puzzle of a conversation with me today it's truly an honor and a pleasure thank you thank you i really enjoyed it thanks lex thanks for listening to this conversation with demas establish to support this podcast please check out our sponsors in the description and now let me leave you with some words from edskar dykstra computer science is no more about computers than\n\nout our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough to interview you well i'll be impressed if if you were i'd be impressed by myself if you were i don't think we're quite up to that yet but uh maybe you're from the future lex if you did would you tell me is that is that a good thing to tell a language model that's tasked with interviewing that it is in fact um ai maybe we're in a kind of meta turing test uh probably probably it would be a good idea not to tell you so it doesn't change your behavior right this is a kind of heisenberg uncertainty principle situation if i told you you behave differently yeah maybe that's what's happening with us of course this is a benchmark from the future where they replay 2022 as a year before ais were good enough yet and now we want to see is it going to pass exactly if i was such a program would you be\n\ndemas establish to support this podcast please check out our sponsors in the description and now let me leave you with some words from edskar dykstra computer science is no more about computers than astronomy is about telescopes thank you for listening and hope to see you next time",
#  'question': 'who is Demis'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
# !pip install -q youtube-transcript-api langchain-community langchain-openai \
               faiss-cpu tiktoken python-dotenv

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %%
video_id = "VAzKqh00g3c"
try:
    transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=["en"])

    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video.")
# Out:
# When Demis Hassabas won the Nobel Prize last year, he celebrated by playing poker with a world champion of chess. Habisas loves a game, which is how he became a pioneer of artificial intelligence. The 48-year-old British scientist is co-founder and CEO of Google's AI powerhouse called Deep Mind. We met two years ago when chatbots announced a new age. Now, Habisas and others are chasing what's called artificial general intelligence, a silicon intellect as versatile as a human, but with superhuman speed and knowledge. After his Nobel and a nighthood from King Charles, we hurried back to London to see what's next from a genius who may hold the cards of our future. What's always guided me and and and the passion I've always had is understanding the world around us. I've always been um since I was a kid fascinated by the biggest questions, you know, the the the meaning of of life, the the the nature of consciousness, the nature of reality itself. I've loved reading about all the great scientists who've worked on these problems and the philosophers and I wanted to uh see if we could advance human knowledge and for me my expression of doing that was to build what I think is the ultimate tool for for advancing human knowledge which is which is AI. We sat down in this room two years ago and I wonder if AI is moving faster today than you imagined. It's moving incredibly fast. uh I think we are on some kind of exponential curve of improvement. Of course, the success of the field in the last few years has attracted even more attention, more resources, more talent. So, um that's adding to the to this exponential progress, exponential curve, in other words, straight up. Yep. Straight up and increasing speed of progress. Start. Yeah, we saw the progress. Hello, Scott. It's nice to see you again. in an artificial companion that can see and hear and chat about anything. Early chatbots learned only the internet. An app called Astra also takes in the world. Do we call her she? Um, it's a good question. I'm not sure we I'm not sure we all know the answer yet. Bibbo Shu is product manager for Project Astra, an app in a new generation of chatbots that interpret the world with their own eyes. We challenged Astra with virtual paintings we chose and showed to Astra for the first time. This is July Hi by Thomas Hartbenton from 1942. How about this one? That is the Virgin of Charity by Elgreco. That painting is Ottomat by Edward Hopper. The person in the painting, what emotion is she exhibiting? The subject in the painting appears pensive and contemplative. Her expression suggesting a sense of solitude. Can you create a story around this picture? It's a chilly evening in the city, a Tuesday perhaps. The woman perhaps named Eleanor sits alone in the diner. She is feeling melancholy due to the uncertainty of her future and the weight of unfulfilled dreams. The scene freezes in time. Only the flow of ideas moving onward. That line, only the flow of ideas moving onward. I wish I'd written that. And did we hear a limit to Astra's patience? What was that fictional conversation about? Ah, in the story I imagined, Eleanor and her friend talked about their shared dreams and the challenges of pursuing them. Something about the way you said ah made me wonder if you were getting bored. I apologize if my tone came across that way. My aim is always to engage thoughtfully. And she said, "Well, I'm sorry if you don't like my tone." Wow. What's happening there? Well, that's interesting. That's again in challenge with these systems as they act in the moment with the context that's around them and that may have never been tested before. He's often surprised because AI programs are sent out on the internet to learn for themselves. They can return later with unexpected skills. So we have theories about what kinds of uh capabilities these systems will have. That's obviously what we try to build into the architectures. But at the end of the day, how it learns, what it picks u ...

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([transcript])

# %%
len(chunks)
# Out:
# 92

# %%
chunks[30]
# Out:
# Document(metadata={}, page_content="in that process. You can ask a follow-up question. Salon hopes this new vision technology can be incorporated into Kmigo and available to students and teachers in 2 to 3 years, but he wants it to undergo more robust testing and meet strict guidelines for privacy and data security. I can imagine a lot of teachers watching this and thinking, okay, well, this is just going to replace me. Why would I want this in my classroom? It's like a Trojan horse. I'm pretty confident that teaching any job that is has a very human centric element of it is as long as it adapts reasonably well in this AI world they're going to be some of the safest jobs out there. You think there will always be a need for teachers in a classroom talking with the student looking the student in the eye. Oh yeah. I mean that's what I'll always want for my own children and frankly for anyone's children. And the hope here is that we can use artificial intelligence and other technologies to amplify what a teacher can do so")

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: 'e43bf5ce-5d8a-4f48-8630-d28a113b5efd',
#  1: '91f21bc4-8108-48bb-a39f-529d85a08f0d',
#  2: 'd003f05b-5457-4ae1-ae75-fe85c296f28a',
#  3: '36f14a83-eb7e-46a2-931d-46bfc102c49e',
#  4: '361ee6e2-81d4-4755-a731-fcdf90cb590c',
#  5: '662c1809-5a1b-4315-8e40-01de7872080c',
#  6: 'e457c372-ff3e-4577-a9bb-ffcd2e50772c',
#  7: '64769cdb-1f94-48ac-8ac0-be8ced0511d5',
#  8: 'f8be4e7e-d04e-42ed-9d34-c50d0f803ac2',
#  9: '47e331fc-a72c-4c71-a60e-0d3314b5c275',
#  10: '233d5f4b-26cc-47b1-99b9-d063a9e7afc5',
#  11: '31857a61-287c-4249-951c-56c5f31fdd46',
#  12: '4a743b6e-1afc-44c7-9457-0ddb510da6e7',
#  13: '95efc86d-feba-44f4-a994-9d4f96acb03d',
#  14: 'fc5555b5-9c00-4bde-85b2-57aea710da71',
#  15: 'f5fb09c7-1db6-45b9-9155-95ab27ec221e',
#  16: '4cf4ffa2-6e96-4180-9e2f-ab83848abfe2',
#  17: 'bdf025c9-d72a-41dd-b757-b96aa71f2ea7',
#  18: 'ba037930-d622-4c55-9076-105af0912ef0',
#  19: '2e22d35b-4c20-4416-834e-52fbecceb038',
#  20: '8c576a94-cb41-4080-816d-daee9ec1b1a7',
#  21: 'fac15f48-a401-493a-9dec-ca0965621a4b',
#  22: 'cd0eee8b-3d3d-4ef2-a3da-7f45455ac30a',
#  23: '5db65eb3-73f4-4849-a427-bd9ae423da64',
#  24: 'c99c491b-b240-4d22-9cad-dc2a27bab702',
#  25: 'c4a9cf16-be11-4a94-a056-0fb0715caad5',
#  26: '7fa84862-22d9-495a-98c4-2eadb2ea69b3',
#  27: 'c2e5db34-2f2e-4073-8375-b73db5056fa0',
#  28: 'b82fd0b3-252f-4fac-80f4-36a27feacd42',
#  29: '412748f5-1f26-4f9b-9bdc-10b47e8b9982',
#  30: 'e8511cdd-84e9-46d8-bdff-9b265e98b6b6',
#  31: 'ff942437-16f1-4eb9-955c-efc9619755f1',
#  32: '5cddbd01-5860-413f-88d2-8c588052e319',
#  33: 'b71d09b6-53f0-4071-bf29-cbea21fd2f6a',
#  34: '19ceac64-327a-4888-aa3f-690bc694c553',
#  35: '288bc4e9-1403-4a12-ac4f-bddbfa47b8c7',
#  36: '39778a4a-2d1c-4e0e-a576-c3130037d1a5',
#  37: '99699638-c7a1-4185-aa55-92c28cb7904b',
#  38: 'eadf284d-5211-469b-bd62-795f33279ff8',
#  39: 'da9d70b1-121e-46c9-805d-2b4e093c0ae5',
#  40: 'f8c9f18f-2b1b-4a98-92e2-54b7e3093e0d',
#  41: '8c74e7ef-612d-4767-a45d-e4648bff9ab3',
#  42: '44dfeba1-c41f-4bf5-abc0-aa59e70eab29',
#  43: '8e680380-f49f-4601-9324-1246b0ffaf1e',
#  44: 'ab0870d9-ad81-486f-9661-5f2ce644a48e',
#  45: '4b7e5ac0-2529-414c-b76b-94f3e9755253',
#  46: 'a4ad5e18-ab13-4d99-8082-67a23c4faa81',
#  47: 'fd01832e-3653-46f1-94e9-72c232425159',
#  48: '907ed454-fe99-4675-ae9f-243404ae497c',
#  49: '54387afc-f945-4cda-910d-b444e693dfb8',
#  50: '5b433a96-4258-4cf3-b890-962988f4b908',
#  51: '2a3e4985-6f0b-4ba3-8d2d-7677821fb751',
#  52: '24302863-2e57-4a30-a144-e31bba141b43',
#  53: 'ef96a024-c960-4422-b6a5-93e33bbea390',
#  54: '63025f67-6f3b-4999-9f38-fa265fa94195',
#  55: '6db8d0f8-d698-40eb-a939-68c7c1f13782',
#  56: 'adbdf5dd-98ee-49ea-b569-3710a3dc2aa5',
#  57: '5ab8b808-840a-44ec-a6f0-e6ef3b5d42ea',
#  58: 'd535e294-0e86-4249-b2b8-cf0cb73d967d',
#  59: '9b8c57f5-efd0-4c58-8a30-080d1c4a7ef6',
#  60: 'b98c6fb8-52a6-4a58-8f77-918155a8a23c',
#  61: '42d27c71-b443-422b-990e-b7fbcb4ab367',
#  62: '177738c3-39b4-415d-a874-36bb0972e932',
#  63: 'fb3ab853-99bd-4b5c-ad53-37024347eb5e',
#  64: '40be316a-0656-4520-aa15-00325a48778d',
#  65: '2042ddd7-6337-4f79-b9ac-6e061a7ae6ff',
#  66: '144c2160-b678-4fa9-8b69-e13624849f54',
#  67: 'bcc36163-d163-4acb-b753-7c5b0aaa14ed',
#  68: '28c6080f-38c7-4c63-bb7a-116ff087857c',
#  69: 'e9d9be5d-043d-4147-889f-75151a0ad5d8',
#  70: 'bf70615f-bca8-4554-844e-28513353e5d6',
#  71: 'a0649bcc-7a91-4d9b-ab44-7e6025da8f12',
#  72: '72b2e6aa-37bf-4324-a72f-2aeaa4ac07c6',
#  73: '49874aa1-d89b-4fb9-a1cf-5842a9b963e8',
#  74: '43eb72ad-fa20-4a22-9abc-d11c026675f5',
#  75: 'e1576b55-8d34-4300-a156-679c9bb2d5da',
#  76: 'e20ccdc4-3f9c-4a7c-ac45-3001b54035ba',
#  77: '200b7aca-7449-41e8-82ea-592a9ed486cc',
#  78: 'ac69d1fa-00e4-42f7-b90e-5d9bfa2f9228',
#  79: '3bb36187-6d0b-4bf9-bf31-58a46ea30f1c',
#  80: 'c0a7ce8e-05a5-4ecc-99f6-2f2fa0af4acd',
#  81: 'ab0d916a-b94b-4b50-aa10-f692946825ca',
#  82: 'fe4bc8a4-fbee-483c-bc13-aadf0d0d96b5',
#  83: 'da9d9532-8dda-4ad5-8cd0-daf21dcd1c57',
#  84: '6c0e348d-8948-4b7f-8c23-1cac2d63a8ba',
#  85: '7a4b923d-b6e3-4e66-b9cf-71a17a240a2e',
#  86: '0e6262e9-2e76-4dbc-9f0f-a4b5e9db1f92',
#  87: '5d38602f-8573-4081-94cb-3ceb984fa7a0',
#  88: '4627f2f1-7620-4b3b-b9c9-cc085e0b0646',
#  89: 'c5c9f7fe-2915-483b-8bab-35e58c93b578',
#  90: 'bddecf5a-cc1d-476a-95c9-ffc99b1c01d0',
#  91: 'd1958045-8cee-4be3-840b-4fb45b49cf1e'}

# %%
vector_store.get_by_ids(['c157bfdd-d529-48c8-b459-bdfb746d1591'])
# Out:
# []

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 2})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7ece1a851f50>, search_kwargs={'k': 2})

# %%
retriever.invoke('what is AIagent')
# Out:
# [Document(id='c0a7ce8e-05a5-4ecc-99f6-2f2fa0af4acd', metadata={}, page_content='between smart weapons and dumb weapons. Lucky showed us how those so-called smart weapons can be synchronized on Andrew\'s AI platform. It\'s called Lattis. Lattis collects data from various sensors and sources, including satellites, drones, radar, and cameras, allowing, he says, the AI to analyze, move assets, and execute missions faster than a human. If you were having to require the human operator to actually map every single action and say, "Hey, do this, if that, then this." It would take so long to manage it that you would be better off just remotely piloting it. If it\'s the AI on board all these weapons that makes it possible to make it so easy. There are lots of people who go, "Oh, AI, I don\'t know. I don\'t trust it. It\'s going to go rogue." I would say that it is something to be aware of, but in the grand scheme of things, things to be afraid of, there\'s things that I\'m much more terrified of, and I\'m a lot more worried about evil people with mediocre advances in technology'),
#  Document(id='fb3ab853-99bd-4b5c-ad53-37024347eb5e', metadata={}, page_content="army of millions toiling to make AI run smoothly. They're called humans in the loop. People sorting, labeling, and sifting reams of data to train and improve AI for companies like Meta, Open AI, Microsoft, and Google. It's grunt work that needs to be done accurately, fast, and to do it cheaply, it's often farmed out to places like Africa. The robots or the machines, you are teaching them how to think like human and to do things like human. We met Naftali Wambalo in Nairobi, Kenya. One of the main hubs for this kind of work. It's a country desperate for jobs because of an unemployment rate as high as 67% among young people. So Naftali, father of two, college educated with a degree in mathematics, was elated to finally find work in an emerging field, artificial intelligence. You were labeling. I did labeling for videos and images. Naftali and digital workers like him spend eight hours a day in front of a screen studying photos and videos, drawing boxes around objects and labeling them,")]

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2)

# %%
prompt = PromptTemplate(
    template="""
      You are a computer scientist.
      Answer ONLY from the provided transcript context.
      If the context is insufficient, just say you don't know.

      {context}
      Question: {question}
    """,
    input_variables = ['context', 'question']
)

# %%
question          = "is the topic of agents discussed in this video? if yes then what was discussed"
retrieved_docs    = retriever.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='95efc86d-feba-44f4-a994-9d4f96acb03d', metadata={}, page_content="limits built into the system. And I wonder if the race for AI dominance is a race to the bottom for safety. So that's one of my big worries actually is that of course all of this energy and racing and resources is great for progress but it might incentivize certain actors in in that to cut corners and one of the corners that can be shortcut would be safety and responsibility. Um so the question is is how can we uh coordinate more you know as leading players but also nation states even I think this is an international thing. AI is going to affect every country, everybody in the world. Um, so I think it's really important that the world uh and the international community has a say in this. Can you teach an AI agent morality? I think you can. They learn by demonstration. They learn by teaching. Um, and I think that's one of the things we have to do with these systems is to give them uh a value system and a and a guidance and some guard rails around that much in the way that you would"),
#  Document(id='d003f05b-5457-4ae1-ae75-fe85c296f28a', metadata={}, page_content="to the to this exponential progress, exponential curve, in other words, straight up. Yep. Straight up and increasing speed of progress. Start. Yeah, we saw the progress. Hello, Scott. It's nice to see you again. in an artificial companion that can see and hear and chat about anything. Early chatbots learned only the internet. An app called Astra also takes in the world. Do we call her she? Um, it's a good question. I'm not sure we I'm not sure we all know the answer yet. Bibbo Shu is product manager for Project Astra, an app in a new generation of chatbots that interpret the world with their own eyes. We challenged Astra with virtual paintings we chose and showed to Astra for the first time. This is July Hi by Thomas Hartbenton from 1942. How about this one? That is the Virgin of Charity by Elgreco. That painting is Ottomat by Edward Hopper. The person in the painting, what emotion is she exhibiting? The subject in the painting appears pensive and contemplative. Her expression")]

# %%
context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
context_text
# Out:
# "limits built into the system. And I wonder if the race for AI dominance is a race to the bottom for safety. So that's one of my big worries actually is that of course all of this energy and racing and resources is great for progress but it might incentivize certain actors in in that to cut corners and one of the corners that can be shortcut would be safety and responsibility. Um so the question is is how can we uh coordinate more you know as leading players but also nation states even I think this is an international thing. AI is going to affect every country, everybody in the world. Um, so I think it's really important that the world uh and the international community has a say in this. Can you teach an AI agent morality? I think you can. They learn by demonstration. They learn by teaching. Um, and I think that's one of the things we have to do with these systems is to give them uh a value system and a and a guidance and some guard rails around that much in the way that you would\n\nto the to this exponential progress, exponential curve, in other words, straight up. Yep. Straight up and increasing speed of progress. Start. Yeah, we saw the progress. Hello, Scott. It's nice to see you again. in an artificial companion that can see and hear and chat about anything. Early chatbots learned only the internet. An app called Astra also takes in the world. Do we call her she? Um, it's a good question. I'm not sure we I'm not sure we all know the answer yet. Bibbo Shu is product manager for Project Astra, an app in a new generation of chatbots that interpret the world with their own eyes. We challenged Astra with virtual paintings we chose and showed to Astra for the first time. This is July Hi by Thomas Hartbenton from 1942. How about this one? That is the Virgin of Charity by Elgreco. That painting is Ottomat by Edward Hopper. The person in the painting, what emotion is she exhibiting? The subject in the painting appears pensive and contemplative. Her expression"

# %%
final_prompt = prompt.invoke({"context": context_text, "question": question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n      You are a computer scientist.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don't know.\n\n      limits built into the system. And I wonder if the race for AI dominance is a race to the bottom for safety. So that's one of my big worries actually is that of course all of this energy and racing and resources is great for progress but it might incentivize certain actors in in that to cut corners and one of the corners that can be shortcut would be safety and responsibility. Um so the question is is how can we uh coordinate more you know as leading players but also nation states even I think this is an international thing. AI is going to affect every country, everybody in the world. Um, so I think it's really important that the world uh and the international community has a say in this. Can you teach an AI agent morality? I think you can. They learn by demonstration. They learn by teaching. Um, and I think that's one of the things we have to do with these systems is to give them uh a value system and a and a guidance and some guard rails around that much in the way that you would\n\nto the to this exponential progress, exponential curve, in other words, straight up. Yep. Straight up and increasing speed of progress. Start. Yeah, we saw the progress. Hello, Scott. It's nice to see you again. in an artificial companion that can see and hear and chat about anything. Early chatbots learned only the internet. An app called Astra also takes in the world. Do we call her she? Um, it's a good question. I'm not sure we I'm not sure we all know the answer yet. Bibbo Shu is product manager for Project Astra, an app in a new generation of chatbots that interpret the world with their own eyes. We challenged Astra with virtual paintings we chose and showed to Astra for the first time. This is July Hi by Thomas Hartbenton from 1942. How about this one? That is the Virgin of Charity by Elgreco. That painting is Ottomat by Edward Hopper. The person in the painting, what emotion is she exhibiting? The subject in the painting appears pensive and contemplative. Her expression\n      Question: is the topic of agents discussed in this video? if yes then what was discussed\n    ")

# %%
answer = llm.invoke(final_prompt)
print(answer.content)
# Out:
# Yes, the topic of agents is discussed in the video. Specifically, it mentions an artificial companion called Astra, which is a new generation of chatbot that can see and hear, and interpret the world with its own eyes. The discussion includes how Astra was challenged with virtual paintings and how it responds to questions about the emotions exhibited by subjects in those paintings.

# %% [markdown]
# building chain

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('who is futurepedia')
# Out:
# {'context': "openly advertised, easy to use, and as Franchesca Mani found out, there isn't much that's been done to stop them. When you first heard the rumor, you didn't know that there were photos or a photo of you? No, we didn't know. I think that was like the most chaotic day I've ever witnessed. In a school, somebody gets an inkling of something and it just spreads. It's like rapid fire. It just goes through everyone. And so then when someone hears hears this, it's like, wait, like AI? Like no one thinks that could like happen to you. Franchesca Mani knew nothing about Nutify websites when she discovered she and several of the girls at Westfield High School in New Jersey had been targeted. According to a lawsuit later filed by one of the other girls through her parents, a boy at the school uploaded photos from Instagram to a site called Clothoff. We're naming the site to raise awareness of its potential dangers. There are more than a hundred of these Nutify websites. A quick search is all it\n\nof homeschooling him and his three sisters. Lucky says he was fascinated by electronics and spent a lot of time tinkering in his parents' garage in Long Beach, California. By age 19, his tinkering turned into Oculus, the virtual reality company. And at 21, Palmer Lucky fulfilled every young founder's dream when he sold Oculus to Facebook for $2 billion. The Wonder Kid graced the covers of magazines, but two years later, he was fired from Facebook. Why did you get fired? Well, you know, everyone's got a different story, but it boils down to I gave $9,000 to a political group that was for Donald Trump and against Hillary Clinton. To be a Trump supporter in 2016, you know, this was at the height of the election insanity and derangement in Silicon Valley. And so, I think that a lot of people thought back then that you could you could just fire a Trump supporter. Facebook founder Mark Zuckerberg has denied that Lucky was fired for his political views. What do you think now when you see",
#  'question': 'who is futurepedia'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke('Can you summarize the video')
# Out:
# 'The video discusses the excitement and potential of new vision technology being developed by Sal Khan and his team, in collaboration with Greg Brockman from OpenAI. This technology aims to enhance educational tools like Kmigo, making them available to students and teachers within 2 to 3 years. The technology allows for real-time interaction through live video, enabling AI to assist with lessons, such as anatomy quizzes, by recognizing drawings and providing feedback. The overall sentiment is one of wonder at the capabilities of AI and its application in education.'
